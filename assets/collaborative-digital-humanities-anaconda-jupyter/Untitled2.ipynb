# %%
variable = "hello, world"
print(variable)
# Out:
# hello, world

# %% [raw]
# # Sample Heading
# ## subpoint 1
# ## subpoint 2

# %% [markdown]
# # Sample Heading
# ## subpoint 1
# ## subpoint 2

# %%
a = 9999

# %%
print(a)
# Out:
# 9999
