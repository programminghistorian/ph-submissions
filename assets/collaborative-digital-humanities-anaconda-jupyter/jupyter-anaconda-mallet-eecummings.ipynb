# %% [markdown]
# # Jupyter + Python + MALLET  + ee cummings

# %% [markdown]
# >This is an example of what's possible with a notebook. Here we demonstrate calling MALLET (a very popular tool in digital humanities research) from python using a core python NLP package (gensim). In our example, we'll fit an LDA topic model on a collection of ee cummings poems. By combining anaconda, jupyter, python and MALLET, we can make our NLP analysis more easily reproducible and sharable.
#
# >In this example, we're using a very small corpus (only 40 or so poems). Realistically you will have many more documents.

# %% [markdown]
# ## Download the latest version of MALLET to your local computer.
#
# >This set of commands works only on `unix` and `mac`. If you're working on `windows`, please follow the MALLET installation instructions described [here](https://programminghistorian.org/lessons/topic-modeling-and-mallet#installing-mallet)
#
# >N.B. Run `bash` commands directly from your notebook by preceding with `!`

# %%
! wget http://mallet.cs.umass.edu/dist/mallet-2.0.8.tar.gz # select desired MALLET version
! gunzip -d mallet-2.0.8.tar.gz -f
! tar -xvf mallet-2.0.8.tar
# Out:
# --2017-08-07 23:50:58--  http://mallet.cs.umass.edu/dist/mallet-2.0.8.tar.gz
# Resolving mallet.cs.umass.edu... 128.119.246.70
# Connecting to mallet.cs.umass.edu|128.119.246.70|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14868234 (14M) [application/x-gzip]
# Saving to: ‘mallet-2.0.8.tar.gz’
#
# mallet-2.0.8.tar.gz 100%[===================>]  14.18M  5.03MB/s    in 2.8s
#
# 2017-08-07 23:51:00 (5.03 MB/s) - ‘mallet-2.0.8.tar.gz’ saved [14868234/14868234]
#
# x ./._mallet-2.0.8
# x mallet-2.0.8/
# x mallet-2.0.8/._bin
# x mallet-2.0.8/bin/
# x mallet-2.0.8/._build.xml
# x mallet-2.0.8/build.xml
# x mallet-2.0.8/class/
# x mallet-2.0.8/dist/
# x mallet-2.0.8/._lib
# x mallet-2.0.8/lib/
# x mallet-2.0.8/._LICENSE
# x mallet-2.0.8/LICENSE
# x mallet-2.0.8/._Makefile
# x mallet-2.0.8/Makefile
# x mallet-2.0.8/._pom.xml
# x mallet-2.0.8/pom.xml
# x mallet-2.0.8/._README.md
# x mallet-2.0.8/README.md
# x mallet-2.0.8/._sample-data
# x mallet-2.0.8/sample-data/
# x mallet-2.0.8/._src
# x mallet-2.0.8/src/
# x mallet-2.0.8/._stoplists
# x mallet-2.0.8/stoplists/
# x mallet-2.0.8/test/
# x mallet-2.0.8/stoplists/._de.txt
# x mallet-2.0.8/stoplists/de.txt
# x mallet-2.0.8/stoplists/._en.txt
# x mallet-2.0.8/stoplists/en.txt
# x mallet-2.0.8/stoplists/._fi.txt
# x mallet-2.0.8/stoplists/fi.txt
# x mallet-2.0.8/stoplists/._fr.txt
# x mallet-2.0.8/stoplists/fr.txt
# x mallet-2.0.8/stoplists/._jp.txt
# x mallet-2.0.8/stoplists/jp.txt
# x mallet-2.0.8/stoplists/._README
# x mallet-2.0.8/stoplists/README
# x mallet-2.0.8/src/._cc
# x mallet-2.0.8/src/cc/
# x mallet-2.0.8/src/cc/._mallet
# x mallet-2.0.8/src/cc/mallet/
# x mallet-2.0.8/src/cc/mallet/._classify
# x mallet-2.0.8/src/cc/mallet/classify/
# x mallet-2.0.8/src/cc/mallet/._cluster
java
# x mallet-2.0.8/src/cc/mallet/pipe/._SaveDataInSource.java
# x mallet-2.0.8/src/cc/mallet/pipe/SaveDataInSource.java
# x mallet-2.0.8/src/cc/mallet/pipe/._SelectiveSGML2TokenSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/SelectiveSGML2TokenSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/._SerialPipes.java
# x mallet-2.0.8/src/cc/mallet/pipe/SerialPipes.java
# x mallet-2.0.8/src/cc/mallet/pipe/._SGML2TokenSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/SGML2TokenSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/._SimpleTaggerSentence2StringTokenization.java
# x mallet-2.0.8/src/cc/mallet/pipe/SimpleTaggerSentence2StringTokenization.java
# x mallet-2.0.8/src/cc/mallet/pipe/._SimpleTaggerSentence2TokenSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/SimpleTaggerSentence2TokenSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/._SimpleTokenizer.java
# x mallet-2.0.8/src/cc/mallet/pipe/SimpleTokenizer.java
# x mallet-2.0.8/src/cc/mallet/pipe/._SourceLocation2TokenSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/SourceLocation2TokenSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/._StringAddNewLineDelimiter.java
# x mallet-2.0.8/src/cc/mallet/pipe/StringAddNewLineDelimiter.java
# x mallet-2.0.8/src/cc/mallet/pipe/._StringList2FeatureSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/StringList2FeatureSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/._SvmLight2FeatureVectorAndLabel.java
# x mallet-2.0.8/src/cc/mallet/pipe/SvmLight2FeatureVectorAndLabel.java
# x mallet-2.0.8/src/cc/mallet/pipe/._Target2Double.java
# x mallet-2.0.8/src/cc/mallet/pipe/Target2Double.java
# x mallet-2.0.8/src/cc/mallet/pipe/._Target2FeatureSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/Target2FeatureSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/._Target2Integer.java
# x mallet-2.0.8/src/cc/mallet/pipe/Target2Integer.java
# x mallet-2.0.8/src/cc/mallet/pipe/._Target2Label.java
# x mallet-2.0.8/src/cc/mallet/pipe/Target2Label.java
# x mallet-2.0.8/src/cc/mallet/pipe/._Target2LabelSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/Target2LabelSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TargetRememberLastLabel.java
# x mallet-2.0.8/src/cc/mallet/pipe/TargetRememberLastLabel.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TargetStringToFeatures.java
# x mallet-2.0.8/src/cc/mallet/pipe/TargetStringToFeatures.java
# x mallet-2.0.8/src/cc/mallet/pipe/._tests
# x mallet-2.0.8/src/cc/mallet/pipe/tests/
# x mallet-2.0.8/src/cc/mallet/pipe/._Token2FeatureVector.java
# x mallet-2.0.8/src/cc/mallet/pipe/Token2FeatureVector.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TokenSequence2FeatureSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/TokenSequence2FeatureSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TokenSequence2FeatureSequenceWithBigrams.java
# x mallet-2.0.8/src/cc/mallet/pipe/TokenSequence2FeatureSequenceWithBigrams.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TokenSequence2FeatureVectorSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/TokenSequence2FeatureVectorSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TokenSequence2TokenInstances.java
# x mallet-2.0.8/src/cc/mallet/pipe/TokenSequence2TokenInstances.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TokenSequenceLowercase.java
# x mallet-2.0.8/src/cc/mallet/pipe/TokenSequenceLowercase.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TokenSequenceMatchDataAndTarget.java
# x mallet-2.0.8/src/cc/mallet/pipe/TokenSequenceMatchDataAndTarget.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TokenSequenceNGrams.java
# x mallet-2.0.8/src/cc/mallet/pipe/TokenSequenceNGrams.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TokenSequenceParseFeatureString.java
# x mallet-2.0.8/src/cc/mallet/pipe/TokenSequenceParseFeatureString.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TokenSequenceRemoveNonAlpha.java
# x mallet-2.0.8/src/cc/mallet/pipe/TokenSequenceRemoveNonAlpha.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TokenSequenceRemoveStopPatterns.java
# x mallet-2.0.8/src/cc/mallet/pipe/TokenSequenceRemoveStopPatterns.java
# x mallet-2.0.8/src/cc/mallet/pipe/._TokenSequenceRemoveStopwords.java
# x mallet-2.0.8/src/cc/mallet/pipe/TokenSequenceRemoveStopwords.java
# x mallet-2.0.8/src/cc/mallet/pipe/._tsf
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/
# x mallet-2.0.8/src/cc/mallet/pipe/._ValueString2FeatureVector.java
# x mallet-2.0.8/src/cc/mallet/pipe/ValueString2FeatureVector.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._CountMatches.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/CountMatches.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._CountMatchesAlignedWithOffsets.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/CountMatchesAlignedWithOffsets.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._CountMatchesMatching.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/CountMatchesMatching.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._FeaturesInWindow.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/FeaturesInWindow.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._FeaturesOfFirstMention.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/FeaturesOfFirstMention.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._LexiconMembership.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/LexiconMembership.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._OffsetConjunctions.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/OffsetConjunctions.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._OffsetFeatureConjunction.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/OffsetFeatureConjunction.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._OffsetPropertyConjunctions.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/OffsetPropertyConjunctions.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._package.html
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/package.html
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._RegexMatches.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/RegexMatches.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._SequencePrintingPipe.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/SequencePrintingPipe.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._Target2BIOFormat.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/Target2BIOFormat.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._tests
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/tests/
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._TokenFirstPosition.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/TokenFirstPosition.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._TokenText.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/TokenText.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._TokenTextCharNGrams.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/TokenTextCharNGrams.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._TokenTextCharPrefix.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/TokenTextCharPrefix.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._TokenTextCharSuffix.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/TokenTextCharSuffix.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._TokenTextNGrams.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/TokenTextNGrams.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._TrieLexiconMembership.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/TrieLexiconMembership.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/._WordVectors.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/WordVectors.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/tests/._package.html
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/tests/package.html
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/tests/._TestOffsetConjunctions.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/tests/TestOffsetConjunctions.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/tests/._TestOffsetFeatureConjunctions.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/tests/TestOffsetFeatureConjunctions.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/tests/._TestSequencePrintingPipe.java
# x mallet-2.0.8/src/cc/mallet/pipe/tsf/tests/TestSequencePrintingPipe.java
# x mallet-2.0.8/src/cc/mallet/pipe/tests/._package.html
# x mallet-2.0.8/src/cc/mallet/pipe/tests/package.html
# x mallet-2.0.8/src/cc/mallet/pipe/tests/._TestInstancePipe.java
# x mallet-2.0.8/src/cc/mallet/pipe/tests/TestInstancePipe.java
# x mallet-2.0.8/src/cc/mallet/pipe/tests/._TestIterators.java
# x mallet-2.0.8/src/cc/mallet/pipe/tests/TestIterators.java
# x mallet-2.0.8/src/cc/mallet/pipe/tests/._TestPipeUtils.java
# x mallet-2.0.8/src/cc/mallet/pipe/tests/TestPipeUtils.java
# x mallet-2.0.8/src/cc/mallet/pipe/tests/._TestRainbowStyle.java
# x mallet-2.0.8/src/cc/mallet/pipe/tests/TestRainbowStyle.java
# x mallet-2.0.8/src/cc/mallet/pipe/tests/._TestSGML2TokenSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/tests/TestSGML2TokenSequence.java
# x mallet-2.0.8/src/cc/mallet/pipe/tests/._TestSpacePipe.java
# x mallet-2.0.8/src/cc/mallet/pipe/tests/TestSpacePipe.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._ArrayDataAndTargetIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/ArrayDataAndTargetIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._ArrayIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/ArrayIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._ConcatenatedInstanceIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/ConcatenatedInstanceIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._CsvIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/CsvIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._DBInstanceIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/DBInstanceIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._EmptyInstanceIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/EmptyInstanceIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._FileIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/FileIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._FileListIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/FileListIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._FileUriIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/FileUriIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._LineGroupIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/LineGroupIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._LineIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/LineIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._package.html
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/package.html
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._ParenGroupIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/ParenGroupIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._PatternMatchIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/PatternMatchIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._PipeExtendedIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/PipeExtendedIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._PipeInputIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/PipeInputIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._RandomFeatureVectorIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/RandomFeatureVectorIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._RandomTokenSequenceIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/RandomTokenSequenceIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._SegmentIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/SegmentIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._SelectiveFileLineIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/SelectiveFileLineIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._SimpleFileLineIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/SimpleFileLineIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._StringArrayIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/StringArrayIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._tests
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/tests/
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/._UnlabeledFileIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/UnlabeledFileIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/tests/._TestPatternMatchIterator.java
# x mallet-2.0.8/src/cc/mallet/pipe/iterator/tests/TestPatternMatchIterator.java
# x mallet-2.0.8/src/cc/mallet/optimize/._AGIS.java
# x mallet-2.0.8/src/cc/mallet/optimize/AGIS.java
# x mallet-2.0.8/src/cc/mallet/optimize/._BackTrackLineSearch.java
# x mallet-2.0.8/src/cc/mallet/optimize/BackTrackLineSearch.java
# x mallet-2.0.8/src/cc/mallet/optimize/._ConjugateGradient.java
# x mallet-2.0.8/src/cc/mallet/optimize/ConjugateGradient.java
# x mallet-2.0.8/src/cc/mallet/optimize/._GradientAscent.java
# x mallet-2.0.8/src/cc/mallet/optimize/GradientAscent.java
# x mallet-2.0.8/src/cc/mallet/optimize/._GradientBracketLineOptimizer.java
# x mallet-2.0.8/src/cc/mallet/optimize/GradientBracketLineOptimizer.java
# x mallet-2.0.8/src/cc/mallet/optimize/._InvalidOptimizableException.java
# x mallet-2.0.8/src/cc/mallet/optimize/InvalidOptimizableException.java
# x mallet-2.0.8/src/cc/mallet/optimize/._LimitedMemoryBFGS.java
# x mallet-2.0.8/src/cc/mallet/optimize/LimitedMemoryBFGS.java
# x mallet-2.0.8/src/cc/mallet/optimize/._LineOptimizer.java
# x mallet-2.0.8/src/cc/mallet/optimize/LineOptimizer.java
# x mallet-2.0.8/src/cc/mallet/optimize/._Optimizable.java
# x mallet-2.0.8/src/cc/mallet/optimize/Optimizable.java
# x mallet-2.0.8/src/cc/mallet/optimize/._OptimizableCollection.java
class
# x mallet-2.0.8/class/cc/mallet/classify/constraints/ge/MaxEntRangeL2FLGEConstraints$MaxEntL2IndGEConstraint.class
# x mallet-2.0.8/class/cc/mallet/classify/constraints/ge/MaxEntRangeL2FLGEConstraints.class
# x mallet-2.0.8/bin/._classifier2info
# x mallet-2.0.8/bin/classifier2info
# x mallet-2.0.8/bin/._csv2classify
# x mallet-2.0.8/bin/csv2classify
# x mallet-2.0.8/bin/._csv2vectors
# x mallet-2.0.8/bin/csv2vectors
# x mallet-2.0.8/bin/._mallet
# x mallet-2.0.8/bin/mallet
# x mallet-2.0.8/bin/._mallet.bat
# x mallet-2.0.8/bin/mallet.bat
# x mallet-2.0.8/bin/._mallethon
# x mallet-2.0.8/bin/mallethon
# x mallet-2.0.8/bin/._prepend-license.sh
# x mallet-2.0.8/bin/prepend-license.sh
# x mallet-2.0.8/bin/._svmlight2vectors
# x mallet-2.0.8/bin/svmlight2vectors
# x mallet-2.0.8/bin/._text2classify
# x mallet-2.0.8/bin/text2classify
# x mallet-2.0.8/bin/._text2vectors
# x mallet-2.0.8/bin/text2vectors
# x mallet-2.0.8/bin/._vectors2classify
# x mallet-2.0.8/bin/vectors2classify
# x mallet-2.0.8/bin/._vectors2info
# x mallet-2.0.8/bin/vectors2info
# x mallet-2.0.8/bin/._vectors2topics
# x mallet-2.0.8/bin/vectors2topics
# x mallet-2.0.8/bin/._vectors2vectors
# x mallet-2.0.8/bin/vectors2vectors

# %% [markdown]
# N.B.  `Jupyter` directly recognizes some `unix` commands such as `ls`, `rm`, `mkdir`

# %%
ls mallet-2.0.8/bin
# Out:
# classifier2info*    mallet.bat*         text2classify*      vectors2topics*
# csv2classify*       mallethon*          text2vectors*       vectors2vectors*
# csv2vectors*        prepend-license.sh* vectors2classify*
# mallet*             svmlight2vectors*   vectors2info*

# %% [markdown]
# ## Install gensim from the terminal or directly from your notebook

# %%
! conda install gensim --yes
# Out:
# Fetching package metadata ...............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /Users/thomasj/anaconda/envs/prog_hist_env2:
# #
# gensim                    2.3.0               np113py36_0

# %% [markdown]
# ## Topic-model a collection of poems from project Gutenberg.

# %%
import requests

with requests.get("http://www.gutenberg.org/files/36508/36508.txt") as req:
    data = req.text

# %% [markdown]
# ### Find start index and end index of each individual poem

# %%
import re

start = data.index("IN WHOSE SWORD-GREAT STORY SHINE THE DEEDS")
end = data.index("END OF THIS PROJECT GUTENBERG EBOOK EIGHT HARVARD POETS")

titles = [title for title in re.findall("[A-Z][A-Z0-9 \n]+", data[start:end]) if len(title) > 2]
indexes = [data.index(title) for title in titles] + [end]

# %% [markdown]
# ### Split the original gutenberg texts into poem chunks

# %%
documents = []
for begin, end in zip(indexes, indexes[1:]):
    documents.append(data[begin:end])

# %% [markdown]
# ### Transform texts into a gensim-format corpus

# %%
def is_number(word):
    """checks whether a string is a number"""
    try:
        int(word)
        return True
    except ValueError:
        return False

# %%
import re

stoplist = set('for a of the and to in *'.split())


texts = [[word.strip("()\r\n[].*") for word in re.split("[ ( ) \n]",document.lower()) if (word not in stoplist \
                                                                                and word is not None \
                                                                                and word is not ''
                                                                                and not is_number(word)
                                                                                ) ] for document in documents]

# remove words that appear only once

from collections import defaultdict
frequency = defaultdict(int)

for text in texts:
    for token in text:
        frequency[token] += 1

texts = [[token for token in text if (frequency[token] > 1) ]
          for text in texts ]

from pprint import pprint  # pretty-printer
pprint(texts)
# Out:
# [['whose'],
#  ['great',
#   'story',
#   'shine',
#   'deeds',
#   '',
#   '',
#   'thou',
#   'whose',
#   'sword-great',
#   'story',
#   'shine',
#   'deeds',
#   'history',
#   'her',
#   'heroes,',
#   'sounds',
#   'tread',
#   'those',
#   'vast',
#   'armies',
#   'marching',
#   'dead,',
#   'with',
#   'standards',
#   'neighing',
#   'great',
#   'steeds',
#   'moving',
#   'war',
#   'across',
#   'smiling',
#   'meads;',
#   'thou',
#   'by',
#   'whose',
#   'page',
#   'we',
#   'break',
#   'precious',
#   'bread',
#   'dear',
#   'communion',
#   'with',
#   'past,',
#   'wed',
#   'valor,',
#   'battle',
#   'with',
#   'heroic',
#   'breeds;',
#   '',
#   'thou,',
#   'froissart,',
#   'that',
#   'thou',
#   'didst',
#   'love',
#   'pen',
#   'while',
#   'others',
#   'wrote',
#   'steel,',
#   'accept',
#   'all',
#   'praise',
#   'after',
#   'ages,',
#   'hungering',
#   'days',
#   'whom',
#   'old',
#   'glories',
#   'move,',
#   'old',
#   'trumpets',
#   'cry;',
#   'who',
#   "gav'st",
#   'as',
#   'one',
#   'those',
#   'immortal',
#   'men',
#   'his',
#   'life',
#   'that',
#   'his',
#   'fair',
#   'city',
#   'might',
#   'not',
#   'die',
#   '',
#   '',
#   '',
#   ''],
#  ['chorus',
#   'girl',
#   '',
#   '',
#   'when',
#   'thou',
#   'hast',
#   'taken',
#   'thy',
#   'last',
#   'applause,',
#   'when',
#   'final',
#   'curtain',
#   'strikes',
#   'world',
#   'away,',
#   'leaving',
#   'shadowy',
#   'silence',
#   'dismay',
#   'that',
#   'stage',
#   'which',
#   'shall',
#   'not',
#   'know',
#   'thy',
#   'smile',
#   'again,',
#   'lingering',
#   'little',
#   'while',
#   'i',
#   'see',
#   'thee',
#   'then',
#   'ponder',
#   'tinsel',
#   'part',
#   'they',
#   'let',
#   'thee',
#   'play;',
#   'i',
#   'see',
#   'red',
#   'mouth',
#   'tarnished,',
#   'face',
#   'grey,',
#   'smileless',
#   'silent',
#   'eyes',
#   'magdalen',
#   '',
#   'lights',
#   'have',
#   'laughed',
#   'their',
#   'last;',
#   'without,',
#   'street',
#   'darkling,',
#   'awaiteth',
#   'her',
#   'whose',
#   'feet',
#   'have',
#   'trod',
#   'silly',
#   'souls',
#   'men',
#   'golden',
#   'dust',
#   'she',
#   'pauses,',
#   'on',
#   'lintel',
#   'defeat,',
#   'her',
#   'heart',
#   'breaks',
#   'smile--and',
#   'she',
#   'is',
#   'lust',
#   '',
#   'mine',
#   'also,',
#   'little',
#   'painted',
#   'poem',
#   'god',
#   '',
#   'this',
#   'is',
#   'garden:',
#   'colors',
#   'come',
#   'go,',
#   'frail',
#   'azures',
#   'fluttering',
#   'from',
#   "night's",
#   'outer',
#   'wing,',
#   'strong',
#   'silent',
#   'greens',
#   'serenely',
#   'lingering,',
#   'absolute',
#   'lights',
#   'like',
#   'baths',
#   'golden',
#   'snow',
#   'this',
#   'is',
#   'garden:',
#   'pursed',
#   'lips',
#   'do',
#   'blow',
#   'upon',
#   'cool',
#   'flutes',
#   'within',
#   'wide',
#   'glooms,',
#   'sing,',
#   'harps',
#   'celestial',
#   'quivering',
#   'string,',
#   'invisible',
#   'faces',
#   'hauntingly',
#   'slow',
#   '',
#   'this',
#   'is',
#   'garden',
#   'time',
#   'shall',
#   'surely',
#   'reap,',
#   'on',
#   "death's",
#   'blade',
#   'lie',
#   'many',
#   'flower',
#   'curled,',
#   'other',
#   'lands',
#   'where',
#   'other',
#   'songs',
#   'be',
#   'sung;',
#   'yet',
#   'stand',
#   'they',
#   'here',
#   'enraptured,',
#   'as',
#   'among',
#   'slow',
#   'deep',
#   'trees',
#   'perpetual',
#   'sleep',
#   'some',
#   'silver-fingered',
#   'fountain',
#   'steals',
#   'world',
#   '',
#   'it',
#   'may',
#   'not',
#   'always',
#   'be',
#   'so;',
#   'i',
#   'say',
#   'that',
#   'if',
#   'your',
#   'lips,',
#   'which',
#   'i',
#   'have',
#   'loved,',
#   'should',
#   'touch',
#   "another's,",
#   'your',
#   'dear',
#   'strong',
#   'fingers',
#   'clutch',
#   'his',
#   'heart,',
#   'as',
#   'mine',
#   'time',
#   'not',
#   'far',
#   'away;',
#   'if',
#   'on',
#   "another's",
#   'face',
#   'your',
#   'sweet',
#   'hair',
#   'lay',
#   'such',
#   'silence',
#   'as',
#   'i',
#   'know,',
#   'or',
#   'such',
#   'great',
#   'writhing',
#   'words',
#   'as,',
#   'uttering',
#   'overmuch,',
#   'stand',
#   'helplessly',
#   'before',
#   'spirit',
#   'at',
#   'bay;',
#   '',
#   'if',
#   'this',
#   'should',
#   'be,',
#   'i',
#   'say',
#   'if',
#   'this',
#   'should',
#   'be--',
#   'you',
#   'my',
#   'heart,',
#   'send',
#   'me',
#   'little',
#   'word;',
#   'that',
#   'i',
#   'may',
#   'go',
#   'unto',
#   'him,',
#   'take',
#   'his',
#   'hands,',
#   'saying,',
#   'accept',
#   'all',
#   'happiness',
#   'from',
#   'me',
#   'then',
#   'shall',
#   'i',
#   'turn',
#   'my',
#   'face,',
#   'hear',
#   'one',
#   'bird',
#   'sing',
#   'terribly',
#   'afar',
#   'lost',
#   'lands',
#   '',
#   '',
#   '',
#   ''],
#  ['crepuscule',
#   '',
#   '',
#   'i',
#   'will',
#   'wade',
#   'out',
#   'till',
#   'my',
#   'thighs',
#   'are',
#   'steeped',
#   'burn-',
#   'ing',
#   'flowers',
#   'i',
#   'will',
#   'take',
#   'sun',
#   'my',
#   'mouth',
#   'leap',
#   'into',
#   'ripe',
#   'air',
#   'alive',
#   'with',
#   'closed',
#   'eyes',
#   'dash',
#   'against',
#   'darkness',
#   'sleeping',
#   'curves',
#   'my',
#   'body',
#   'shall',
#   'enter',
#   'fingers',
#   'smooth',
#   'mastery',
#   'with',
#   'chasteness',
#   'sea-girls',
#   'will',
#   'i',
#   'complete',
#   'mystery',
#   'my',
#   'flesh',
#   'i',
#   'will',
#   'rise',
#   'after',
#   'thousand',
#   'years',
#   'lipping',
#   'flowers',
#   'set',
#   'my',
#   'teeth',
#   'silver',
#   'moon',
#   '',
#   '',
#   '',
#   ''],
#  ['finis',
#   '',
#   '',
#   'over',
#   'silent',
#   'waters',
#   'day',
#   'descending',
#   'night',
#   'ascending',
#   'floods',
#   'gentle',
#   'glory',
#   'sunset',
#   'golden',
#   'greeting',
#   'splendidly',
#   'westward',
#   'as',
#   'pale',
#   'twilight',
#   'trem-',
#   'bles',
#   'into',
#   'darkness',
#   'comes',
#   'last',
#   "light's",
#   'gracious',
#   'exhortation',
#   'lifting',
#   'up',
#   'peace',
#   'so',
#   'when',
#   'life',
#   'shall',
#   'falter',
#   'standing',
#   'on',
#   'shores',
#   'the',
#   'eternal',
#   'god',
#   'may',
#   'i',
#   'behold',
#   'my',
#   'sunset',
#   'flooding',
#   'over',
#   'silent',
#   'waters',
#   '',
#   '',
#   '',
#   ''],
#  ['lover',
#   'speaks',
#   '',
#   '',
#   'your',
#   'little',
#   'voice',
#   'over',
#   'wires',
#   'came',
#   'leaping',
#   'i',
#   'felt',
#   'suddenly',
#   'dizzy',
#   'with',
#   'jostling',
#   'shouting',
#   'merry',
#   'flowers',
#   'wee',
#   'skipping',
#   'high-heeled',
#   'flames',
#   'courtesied',
#   'before',
#   'my',
#   'eyes',
#   'or',
#   'twinkling',
#   'over',
#   'my',
#   'side',
#   'looked',
#   'up',
#   'with',
#   'impertinently',
#   'exquisite',
#   'faces',
#   'floating',
#   'hands',
#   'were',
#   'laid',
#   'upon',
#   'me',
#   'i',
#   'was',
#   'whirled',
#   'tossed',
#   'into',
#   'delicious',
#   'dancing',
#   'up',
#   'up',
#   'with',
#   'pale',
#   'important',
#   'stars',
#   'humorous',
#   'moon',
#   'dear',
#   'girl',
#   'how',
#   'i',
#   'was',
#   'crazy',
#   'how',
#   'i',
#   'cried',
#   'when',
#   'i',
#   'heard',
#   'over',
#   'time',
#   'tide',
#   'death',
#   'leaping',
#   'sweetly',
#   'your',
#   'voice',
#   '',
#   '',
#   '',
#   ''],
#  [],
#  ['foster',
#   'damon',
#   'j',
#   'r',
#   'dos',
#   'passos',
#   'robert',
#   'hillyer',
#   'r',
#   's',
#   'mitchell',
#   'william',
#   'a',
#   'norris',
#   'dudley',
#   'poore',
#   'cuthbert',
#   'wright',
#   '',
#   'illustration',
#   '',
#   'new',
#   'york',
#   'laurence',
#   'j',
#   'gomme',
#   '',
#   '',
#   '',
#   '',
#   'copyright,',
#   '1917,',
#   'by',
#   'laurence',
#   'j',
#   'gomme',
#   '',
#   'vail-ballou',
#   'company',
#   'binghamton',
#   'new',
#   'york',
#   '',
#   '',
#   '',
#   '',
#   'contents',
#   '',
#   '',
#   'page',
#   'e',
#   'estlin',
#   'cummings',
#   '',
#   'thou',
#   'whose',
#   'sword-great',
#   'story',
#   'shine',
#   'deeds',
#   'chorus',
#   'girl',
#   'this',
#   'is',
#   'garden',
#   'it',
#   'may',
#   'not',
#   'always',
#   'be',
#   'so',
#   'crepuscule',
#   'finis',
#   'lover',
#   'speaks',
#   'epitaph',
#   '',
#   '',
#   's',
#   'foster',
#   'damon',
#   '',
#   'incessu',
#   'patuit',
#   'deus',
#   'you',
#   'thought',
#   'i',
#   'had',
#   'forgotten',
#   'venice',
#   'new',
#   'macaber',
#   'war',
#   'calm',
#   'day,',
#   'with',
#   'rollers',
#   'phonograph--tango',
#   'decoration',
#   'threnody',
#   '',
#   '',
#   'j',
#   'r',
#   'dos',
#   'passos',
#   '',
#   'bridge',
#   'salvation',
#   'army',
#   'incarnation',
#   'memory',
#   'saturnalia',
#   '"whan',
#   'that',
#   'aprille"',
#   'night',
#   'piece',
#   '',
#   '',
#   'robert',
#   'hillyer',
#   '',
#   'four',
#   'sonnets',
#   'from',
#   'sonnet-sequence',
#   'sea',
#   'gull',
#   'domesday',
#   'passepied',
#   'by',
#   'scarlatti',
#   'elegy',
#   'antinous',
#   'song',
#   '"my',
#   'peace',
#   'i',
#   'leave',
#   'with',
#   'you"',
#   'recompense',
#   '',
#   '',
#   'r',
#   's',
#   'mitchell',
#   '',
#   'poppy',
#   'song',
#   'love',
#   'dream',
#   'island',
#   'death',
#   'from',
#   'arabian',
#   'nights',
#   'threnody',
#   'helen',
#   'largo',
#   'lazarus',
#   'crucifix',
#   'neith',
#   'farewell',
#   '',
#   '',
#   'william',
#   'a',
#   'norris',
#   '',
#   'too',
#   'much',
#   'song',
#   'wherever',
#   'my',
#   'dreams',
#   'go',
#   'out',
#   'littleness',
#   'nahant',
#   'qui',
#   'sub',
#   'luna',
#   'errant',
#   'across',
#   'taut',
#   'strings',
#   'escape',
#   'on',
#   'street',
#   'corner',
#   'sea-burial',
#   '',
#   '',
#   'dudley',
#   'poore',
#   '',
#   'renaissance',
#   'picture',
#   "philosopher's",
#   'garden',
#   'tree',
#   'stars',
#   'after',
#   'rain',
#   'cor',
#   'cordium',
#   'withered',
#   'leaf,',
#   'faded',
#   'flower',
#   'be',
#   'mine',
#   '',
#   '',
#   'cuthbert',
#   'wright',
#   '',
#   'end',
#   'it',
#   'new',
#   'platonist',
#   'room',
#   'over',
#   'river',
#   'fiddler',
#   "falstaff's",
#   'page',
#   'dull',
#   'sunday',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'e',
#   'estlin',
#   'cummings',
#   '',
#   '',
#   '',
#   '',
#   'thou',
#   'whose',
#   'sword-great',
#   'story',
#   'shine',
#   'deeds',
#   '',
#   '',
#   'thou',
#   'whose',
#   'sword-great',
#   'story',
#   'shine',
#   'deeds',
#   'history',
#   'her',
#   'heroes,',
#   'sounds',
#   'tread',
#   'those',
#   'vast',
#   'armies',
#   'marching',
#   'dead,',
#   'with',
#   'standards',
#   'neighing',
#   'great',
#   'steeds',
#   'moving',
#   'war',
#   'across',
#   'smiling',
#   'meads;',
#   'thou',
#   'by',
#   'whose',
#   'page',
#   'we',
#   'break',
#   'precious',
#   'bread',
#   'dear',
#   'communion',
#   'with',
#   'past,',
#   'wed',
#   'valor,',
#   'battle',
#   'with',
#   'heroic',
#   'breeds;',
#   '',
#   'thou,',
#   'froissart,',
#   'that',
#   'thou',
#   'didst',
#   'love',
#   'pen',
#   'while',
#   'others',
#   'wrote',
#   'steel,',
#   'accept',
#   'all',
#   'praise',
#   'after',
#   'ages,',
#   'hungering',
#   'days',
#   'whom',
#   'old',
#   'glories',
#   'move,',
#   'old',
#   'trumpets',
#   'cry;',
#   'who',
#   "gav'st",
#   'as',
#   'one',
#   'those',
#   'immortal',
#   'men',
#   'his',
#   'life',
#   'that',
#   'his',
#   'fair',
#   'city',
#   'might',
#   'not',
#   'die',
#   '',
#   '',
#   '',
#   '',
#   'chorus',
#   'girl',
#   '',
#   '',
#   'when',
#   'thou',
#   'hast',
#   'taken',
#   'thy',
#   'last',
#   'applause,',
#   'when',
#   'final',
#   'curtain',
#   'strikes',
#   'world',
#   'away,',
#   'leaving',
#   'shadowy',
#   'silence',
#   'dismay',
#   'that',
#   'stage',
#   'which',
#   'shall',
#   'not',
#   'know',
#   'thy',
#   'smile',
#   'again,',
#   'lingering',
#   'little',
#   'while',
#   'i',
#   'see',
#   'thee',
#   'then',
#   'ponder',
#   'tinsel',
#   'part',
#   'they',
#   'let',
#   'thee',
#   'play;',
#   'i',
#   'see',
#   'red',
#   'mouth',
#   'tarnished,',
#   'face',
#   'grey,',
#   'smileless',
#   'silent',
#   'eyes',
#   'magdalen',
#   '',
#   'lights',
#   'have',
#   'laughed',
#   'their',
#   'last;',
#   'without,',
#   'street',
#   'darkling,',
#   'awaiteth',
#   'her',
#   'whose',
#   'feet',
#   'have',
#   'trod',
#   'silly',
#   'souls',
#   'men',
#   'golden',
#   'dust',
#   'she',
#   'pauses,',
#   'on',
#   'lintel',
#   'defeat,',
#   'her',
#   'heart',
#   'breaks',
#   'smile--and',
#   'she',
#   'is',
#   'lust',
#   '',
#   'mine',
#   'also,',
#   'little',
#   'painted',
#   'poem',
#   'god',
#   '',
#   'this',
#   'is',
#   'garden:',
#   'colors',
#   'come',
#   'go,',
#   'frail',
#   'azures',
#   'fluttering',
#   'from',
#   "night's",
#   'outer',
#   'wing,',
#   'strong',
#   'silent',
#   'greens',
#   'serenely',
#   'lingering,',
#   'absolute',
#   'lights',
#   'like',
#   'baths',
#   'golden',
#   'snow',
#   'this',
#   'is',
#   'garden:',
#   'pursed',
#   'lips',
#   'do',
#   'blow',
#   'upon',
#   'cool',
#   'flutes',
#   'within',
#   'wide',
#   'glooms,',
#   'sing,',
#   'harps',
#   'celestial',
#   'quivering',
#   'string,',
#   'invisible',
#   'faces',
#   'hauntingly',
#   'slow',
#   '',
#   'this',
#   'is',
#   'garden',
#   'time',
#   'shall',
#   'surely',
#   'reap,',
#   'on',
#   "death's",
#   'blade',
#   'lie',
#   'many',
#   'flower',
#   'curled,',
#   'other',
#   'lands',
#   'where',
#   'other',
#   'songs',
#   'be',
#   'sung;',
#   'yet',
#   'stand',
#   'they',
#   'here',
#   'enraptured,',
#   'as',
#   'among',
#   'slow',
#   'deep',
#   'trees',
#   'perpetual',
#   'sleep',
#   'some',
#   'silver-fingered',
#   'fountain',
#   'steals',
#   'world',
#   '',
#   'it',
#   'may',
#   'not',
#   'always',
#   'be',
#   'so;',
#   'i',
#   'say',
#   'that',
#   'if',
#   'your',
#   'lips,',
#   'which',
#   'i',
#   'have',
#   'loved,',
#   'should',
#   'touch',
#   "another's,",
#   'your',
#   'dear',
#   'strong',
#   'fingers',
#   'clutch',
#   'his',
#   'heart,',
#   'as',
#   'mine',
#   'time',
#   'not',
#   'far',
#   'away;',
#   'if',
#   'on',
#   "another's",
#   'face',
#   'your',
#   'sweet',
#   'hair',
#   'lay',
#   'such',
#   'silence',
#   'as',
#   'i',
#   'know,',
#   'or',
#   'such',
#   'great',
#   'writhing',
#   'words',
#   'as,',
#   'uttering',
#   'overmuch,',
#   'stand',
#   'helplessly',
#   'before',
#   'spirit',
#   'at',
#   'bay;',
#   '',
#   'if',
#   'this',
#   'should',
#   'be,',
#   'i',
#   'say',
#   'if',
#   'this',
#   'should',
#   'be--',
#   'you',
#   'my',
#   'heart,',
#   'send',
#   'me',
#   'little',
#   'word;',
#   'that',
#   'i',
#   'may',
#   'go',
#   'unto',
#   'him,',
#   'take',
#   'his',
#   'hands,',
#   'saying,',
#   'accept',
#   'all',
#   'happiness',
#   'from',
#   'me',
#   'then',
#   'shall',
#   'i',
#   'turn',
#   'my',
#   'face,',
#   'hear',
#   'one',
#   'bird',
#   'sing',
#   'terribly',
#   'afar',
#   'lost',
#   'lands',
#   '',
#   '',
#   '',
#   '',
#   'crepuscule',
#   '',
#   '',
#   'i',
#   'will',
#   'wade',
#   'out',
#   'till',
#   'my',
#   'thighs',
#   'are',
#   'steeped',
#   'burn-',
#   'ing',
#   'flowers',
#   'i',
#   'will',
#   'take',
#   'sun',
#   'my',
#   'mouth',
#   'leap',
#   'into',
#   'ripe',
#   'air',
#   'alive',
#   'with',
#   'closed',
#   'eyes',
#   'dash',
#   'against',
#   'darkness',
#   'sleeping',
#   'curves',
#   'my',
#   'body',
#   'shall',
#   'enter',
#   'fingers',
#   'smooth',
#   'mastery',
#   'with',
#   'chasteness',
#   'sea-girls',
#   'will',
#   'i',
#   'complete',
#   'mystery',
#   'my',
#   'flesh',
#   'i',
#   'will',
#   'rise',
#   'after',
#   'thousand',
#   'years',
#   'lipping',
#   'flowers',
#   'set',
#   'my',
#   'teeth',
#   'silver',
#   'moon',
#   '',
#   '',
#   '',
#   '',
#   'finis',
#   '',
#   '',
#   'over',
#   'silent',
#   'waters',
#   'day',
#   'descending',
#   'night',
#   'ascending',
#   'floods',
#   'gentle',
#   'glory',
#   'sunset',
#   'golden',
#   'greeting',
#   'splendidly',
#   'westward',
#   'as',
#   'pale',
#   'twilight',
#   'trem-',
#   'bles',
#   'into',
#   'darkness',
#   'comes',
#   'last',
#   "light's",
#   'gracious',
#   'exhortation',
#   'lifting',
#   'up',
#   'peace',
#   'so',
#   'when',
#   'life',
#   'shall',
#   'falter',
#   'standing',
#   'on',
#   'shores',
#   'the',
#   'eternal',
#   'god',
#   'may',
#   'i',
#   'behold',
#   'my',
#   'sunset',
#   'flooding',
#   'over',
#   'silent',
#   'waters',
#   '',
#   '',
#   '',
#   '',
#   'lover',
#   'speaks',
#   '',
#   '',
#   'your',
#   'little',
#   'voice',
#   'over',
#   'wires',
#   'came',
#   'leaping',
#   'i',
#   'felt',
#   'suddenly',
#   'dizzy',
#   'with',
#   'jostling',
#   'shouting',
#   'merry',
#   'flowers',
#   'wee',
#   'skipping',
#   'high-heeled',
#   'flames',
#   'courtesied',
#   'before',
#   'my',
#   'eyes',
#   'or',
#   'twinkling',
#   'over',
#   'my',
#   'side',
#   'looked',
#   'up',
#   'with',
#   'impertinently',
#   'exquisite',
#   'faces',
#   'floating',
#   'hands',
#   'were',
#   'laid',
#   'upon',
#   'me',
#   'i',
#   'was',
#   'whirled',
#   'tossed',
#   'into',
#   'delicious',
#   'dancing',
#   'up',
#   'up',
#   'with',
#   'pale',
#   'important',
#   'stars',
#   'humorous',
#   'moon',
#   'dear',
#   'girl',
#   'how',
#   'i',
#   'was',
#   'crazy',
#   'how',
#   'i',
#   'cried',
#   'when',
#   'i',
#   'heard',
#   'over',
#   'time',
#   'tide',
#   'death',
#   'leaping',
#   'sweetly',
#   'your',
#   'voice',
#   '',
#   '',
#   '',
#   '',
#   'epitaph',
#   '',
#   '',
#   'tumbling-hair',
#   'picker',
#   'buttercups',
#   'violets',
#   'dandelions',
#   'big',
#   'bullying',
#   'daisies',
#   'through',
#   'field',
#   'wonderful',
#   'with',
#   'eyes',
#   'little',
#   'sorry',
#   'another',
#   'comes',
#   'also',
#   'picking',
#   'flowers',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   's',
#   'foster',
#   'damon',
#   '',
#   '',
#   '',
#   ''],
#  ['incessu',
#   'patuit',
#   'deus',
#   '',
#   '',
#   'little',
#   'clattering',
#   'stones',
#   'along',
#   'street',
#   'dance',
#   'with',
#   'each',
#   'other',
#   'round',
#   'my',
#   'swimming',
#   'feet;',
#   'street',
#   'itself,',
#   'as',
#   'some',
#   'crazy',
#   'dream,',
#   'streaks',
#   'past,',
#   'half-perceived',
#   'material',
#   'stream',
#   '',
#   'brighter',
#   'than',
#   'early',
#   "dawn's",
#   'most',
#   'brilliant',
#   'dye',
#   'are',
#   'blown',
#   'clear',
#   'bands',
#   'color',
#   'through',
#   'sky,',
#   'that',
#   'swirl',
#   'sweep',
#   'meet,',
#   'break',
#   'foam',
#   'like',
#   'rainbow',
#   'veils',
#   'upon',
#   "bubble's",
#   'dome',
#   '',
#   'yours',
#   'are',
#   'songs',
#   'that',
#   'burst',
#   'about',
#   'my',
#   'ears,',
#   'or',
#   'blow',
#   'away',
#   'as',
#   'many-colored',
#   'spheres',
#   '',
#   'you',
#   'are',
#   'star',
#   'that',
#   'made',
#   'skies',
#   'all',
#   'bright,',
#   'yet',
#   'tore',
#   'itself',
#   'away',
#   'flaming',
#   'flight;',
#   'you',
#   'are',
#   'tree',
#   'that',
#   'suddenly',
#   'awoke;',
#   'you',
#   'are',
#   'rose',
#   'that',
#   'came',
#   'life',
#   'spoke',
#   '',
#   'guided',
#   'by',
#   'you,',
#   'how',
#   'we',
#   'might',
#   'stroll',
#   'towards',
#   'death,',
#   'our',
#   'only',
#   'music',
#   'one',
#   "another's",
#   'breath,',
#   'through',
#   'gardens',
#   'intimate',
#   'with',
#   'hollyhocks,',
#   'where',
#   'silent',
#   'poppies',
#   'burn',
#   'between',
#   'rocks,',
#   'by',
#   'pools',
#   'where',
#   'birches',
#   'bend',
#   'confidants',
#   'above',
#   'green',
#   'waters',
#   'scummed',
#   'with',
#   'lily-plants',
#   '',
#   'there',
#   'we',
#   'might',
#   'wander,',
#   'you',
#   'i',
#   'alone,',
#   'through',
#   'gardens',
#   'filled',
#   'with',
#   'marble',
#   'seats',
#   'moss-grown,',
#   'fountains--water-threads',
#   'that',
#   'winds',
#   'disperse--',
#   'while',
#   'spray',
#   'birds',
#   'sit',
#   'converse',
#   '',
#   'when',
#   'fireflies',
#   'mix',
#   'their',
#   'circling',
#   'glow',
#   'through',
#   'dark',
#   'plants,',
#   'then',
#   'gently',
#   'might',
#   'i',
#   'know',
#   'your',
#   'lips,',
#   'light',
#   'as',
#   'wings',
#   'dragon-flies',
#   '',
#   '--merely',
#   'dreams,',
#   'fluttering',
#   'my',
#   'eyes',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['you',
#   'thought',
#   'i',
#   'had',
#   'forgotten',
#   '',
#   '',
#   'you',
#   'thought',
#   'i',
#   'had',
#   'forgotten',
#   'well,',
#   'i',
#   'had!',
#   'although',
#   'i',
#   'never',
#   'guessed',
#   'i',
#   'could',
#   'forget',
#   'those',
#   'few',
#   'great',
#   'moments',
#   'when',
#   'we',
#   'both',
#   'went',
#   'mad',
#   '',
#   '',
#   'other',
#   'day',
#   'at',
#   "someone's",
#   'tea',
#   'we',
#   'met,',
#   'smiling',
#   'gayly,',
#   'bowed,',
#   'went',
#   'our',
#   'several',
#   'ways,',
#   'complacent',
#   'with',
#   'successful',
#   'coldness.--yet',
#   '',
#   'suddenly',
#   'i',
#   'was',
#   'back',
#   'old',
#   'days',
#   'before',
#   'you',
#   'felt',
#   'we',
#   'ought',
#   'drift',
#   'apart',
#   'it',
#   'was',
#   'some',
#   'trick--the',
#   'way',
#   'your',
#   'eyebrows',
#   'raise,',
#   '',
#   'your',
#   'hands--some',
#   'vivid',
#   'trifle',
#   'with',
#   'start',
#   'then',
#   'i',
#   'remembered',
#   'how',
#   'i',
#   'lived',
#   'alone,',
#   'writing',
#   'bad',
#   'poems',
#   'eating',
#   'out',
#   'my',
#   'heart',
#   '',
#   'all',
#   'your',
#   'beauty.--how',
#   'time',
#   'has',
#   'flown!',
#   '',
#   '',
#   '',
#   ''],
#  ['venice',
#   '',
#   '',
#   'sunset',
#   'glowing',
#   'crimson',
#   'gold,',
#   'she',
#   'lies,',
#   'glory',
#   'world,',
#   'beached',
#   "king's",
#   'galley,',
#   'whose',
#   'sails',
#   'are',
#   'furled,',
#   'who',
#   'is',
#   'hung',
#   'with',
#   'tapestries',
#   'rich',
#   'old',
#   '',
#   'beautiful',
#   'as',
#   'woman',
#   'is',
#   'she,',
#   'woman',
#   'whose',
#   'autumn',
#   'life',
#   'is',
#   'here,',
#   'proud',
#   'calm',
#   'at',
#   'end',
#   'year',
#   'with',
#   'grace',
#   'that',
#   'now',
#   'is',
#   'majesty',
#   '',
#   'sleeping',
#   'waters',
#   'bathe',
#   'her',
#   'sides,',
#   'warm,',
#   'blue',
#   'streams',
#   'adrian',
#   'sea;',
#   'she',
#   'dreams',
#   'drowses',
#   'languorously,',
#   'swayed',
#   'swaying',
#   'tides',
#   '',
#   'she',
#   'is',
#   'goddess',
#   'left',
#   'us,',
#   'veiled',
#   'with',
#   'softening',
#   'veils',
#   'time;',
#   'her',
#   'blue-veined',
#   'breasts',
#   'are',
#   'now',
#   'sublime,',
#   'her',
#   'moulded',
#   'torso',
#   'glorious',
#   '',
#   'pity',
#   'that',
#   'we',
#   'must',
#   'come',
#   'go--!',
#   'while',
#   'old',
#   'gold',
#   'marble',
#   'stays,',
#   'forever',
#   'gleaming',
#   'its',
#   'soft',
#   'strong',
#   'blaze,',
#   'calm',
#   'early',
#   'evening',
#   'glow',
#   '',
#   'still',
#   'sensitive',
#   'silhouettes',
#   'gondolas',
#   'pass',
#   'leave',
#   'no',
#   'track,',
#   'light',
#   'on',
#   'tides',
#   'as',
#   'lilies,',
#   'black',
#   'rippling',
#   'waters',
#   'long',
#   'sunsets',
#   '',
#   '',
#   '',
#   ''],
#  ['new',
#   'macaber',
#   '',
#   '',
#   'pleasant',
#   'graveyard',
#   'my',
#   'soul',
#   'with',
#   'sentimental',
#   'cypress',
#   'trees',
#   'flowers',
#   'is',
#   'filled,',
#   'that',
#   'i',
#   'may',
#   'stroll',
#   'meditation,',
#   'at',
#   'my',
#   'ease',
#   '',
#   'little',
#   'marble',
#   'stones',
#   'are',
#   'lost',
#   'flowers',
#   'surging',
#   'from',
#   'dead;',
#   'nor',
#   'is',
#   'there',
#   'any',
#   'mournful',
#   'ghost',
#   'wail',
#   'until',
#   'night',
#   'is',
#   'sped',
#   '',
#   'while',
#   'night',
#   'rustles',
#   'through',
#   'trees,',
#   'dragging',
#   'stars',
#   'along,',
#   'i',
#   'know',
#   'moon',
#   'is',
#   'rising',
#   'on',
#   'breeze,',
#   'quivering',
#   'as',
#   "river's",
#   'flow',
#   '',
#   'ah!',
#   'that',
#   'moon',
#   'silver',
#   'sheen!',
#   'it',
#   'is',
#   'my',
#   'heart',
#   'hung',
#   'sky;',
#   'no',
#   'clouds',
#   'ever',
#   'float',
#   'between',
#   'grave-flowers',
#   'my',
#   'heart',
#   'on',
#   'high',
#   '',
#   'i',
#   'do',
#   'not',
#   'read',
#   'upon',
#   'each',
#   'stone',
#   'name',
#   'that',
#   'once',
#   'was',
#   'carven',
#   'there;',
#   'i',
#   'merely',
#   'note',
#   'new',
#   'blossoms',
#   'blown',
#   'breathe',
#   'perfume',
#   'air',
#   '',
#   'thus',
#   'walk',
#   'i',
#   'through',
#   'my',
#   'wonderland',
#   'while',
#   'all',
#   'evening',
#   'is',
#   'atune,',
#   'beneath',
#   'cypress',
#   'trees',
#   'that',
#   'stand',
#   'like',
#   'candles',
#   'barren',
#   'moon',
#   '',
#   '',
#   '',
#   ''],
#  ['war',
#   '',
#   '',
#   'music',
#   'beats,',
#   'up',
#   'chasmed',
#   'street,',
#   'then',
#   'flares',
#   'from',
#   'around',
#   'curve;',
#   'cheers',
#   'break',
#   'out',
#   'from',
#   'waving',
#   'crowd:',
#   '--our',
#   'soldiers',
#   'march,',
#   'superb!',
#   'over',
#   'track-lined',
#   'city',
#   'street',
#   'young',
#   'men,',
#   'grinning',
#   'men,',
#   'pass',
#   '',
#   'last',
#   'night',
#   'they',
#   'danced',
#   'that',
#   'very',
#   'tune;',
#   'today',
#   'they',
#   'march',
#   'away;',
#   'tomorrow,',
#   'perhaps',
#   'no',
#   'band',
#   'at',
#   'all,',
#   'or',
#   'band',
#   'beside',
#   'grave',
#   'above,',
#   'long',
#   'blue',
#   'strip',
#   'sky,',
#   'whirling',
#   'pigeons,',
#   'thoughtless',
#   'pigeons,',
#   'pass',
#   '',
#   'another',
#   'band',
#   'beats',
#   'down',
#   'street;',
#   'contending',
#   'rhythms',
#   'clash;',
#   'new',
#   'melodies',
#   'win',
#   'place,',
#   'then',
#   'fade,',
#   'flashing',
#   'legs',
#   'move',
#   'past',
#   'down',
#   'cheering,',
#   'grey-paved',
#   'street',
#   'fringed',
#   'flags,',
#   'erect',
#   'flags,',
#   'pass',
#   '',
#   '',
#   '',
#   ''],
#  ['calm', 'day,'],
#  ['with',
#   'rollers',
#   '',
#   '',
#   'always',
#   'ships',
#   'that',
#   'move',
#   'mystery,',
#   'on',
#   'dim',
#   'horizon,',
#   'shadow-filled',
#   'sails',
#   'dreams,',
#   'sliding',
#   'over',
#   'blue-grey',
#   'ocean,',
#   'far',
#   'from',
#   'rock-edged',
#   'shore',
#   'where',
#   'willow-green',
#   'waves',
#   'are',
#   'rushing,',
#   'white',
#   'foam-people',
#   'leap,',
#   'stand',
#   'erect',
#   'moment',
#   '',
#   'ho!',
#   'ye',
#   'sails',
#   'that',
#   'seem',
#   'wander',
#   'dream-filled',
#   'meadows,',
#   'say,',
#   'is',
#   'shore',
#   'where',
#   'i',
#   'stand',
#   'only',
#   'field',
#   'struggle,',
#   'or',
#   'are',
#   'ye',
#   'hit',
#   'battered',
#   'out',
#   'there',
#   'by',
#   'waves',
#   'wind-gusts',
#   'as',
#   'ye',
#   'tack',
#   'over',
#   'clashing',
#   'sea',
#   'watery',
#   'echoes?',
#   '',
#   '',
#   '',
#   ''],
#  [],
#  ['',
#   '',
#   'old',
#   'dances',
#   'are',
#   'simplified',
#   'their',
#   'yearning,',
#   'bleached',
#   'by',
#   'time',
#   'yet',
#   'from',
#   'one',
#   'black',
#   'disc',
#   'we',
#   'tasted',
#   'again',
#   'bite',
#   'crude',
#   'spanish',
#   'passion',
#   '',
#   '',
#   'he',
#   'had',
#   'got',
#   'into',
#   'her',
#   'courtyard',
#   'she',
#   'was',
#   'alone',
#   'that',
#   'night',
#   'through',
#   'black',
#   'night-rain,',
#   'he',
#   'sang',
#   'her',
#   'window',
#   'bars:',
#   '',
#   '_love',
#   'me,',
#   'love--ah,',
#   'love',
#   'me!_',
#   '_if',
#   'you',
#   'will',
#   'not,',
#   'i',
#   'can',
#   'follow_',
#   '_into',
#   'highest',
#   'mountains;_',
#   '_and',
#   'there,',
#   'wooden',
#   'cabin,_',
#   '_i',
#   'will',
#   'strangle',
#   'you',
#   'your',
#   'lover._',
#   '',
#   '--that',
#   'was',
#   'but',
#   'rustling',
#   'dripping',
#   'plants',
#   'dark',
#   'more',
#   'tightly',
#   'under',
#   'his',
#   'cloak,',
#   'he',
#   'clasped',
#   'his',
#   'guitar',
#   '',
#   '_love,',
#   'ah-h!',
#   'love',
#   'me,',
#   'love',
#   'me!_',
#   '_if',
#   'you',
#   'will',
#   'do',
#   'this,',
#   'i',
#   'can',
#   'buy_',
#   '_a',
#   'fringed',
#   'silk',
#   'scarf',
#   'yellow,_',
#   '_a',
#   'high',
#   'comb',
#   'carved',
#   'tortoise;_',
#   '_then',
#   'we',
#   'will',
#   'dance',
#   'plaza._',
#   '',
#   'she',
#   'was',
#   'alone',
#   'that',
#   'night',
#   'he',
#   'had',
#   'broken',
#   'into',
#   'her',
#   'courtyard',
#   'above',
#   'gurgling',
#   'gutters',
#   'he',
#   'heard--',
#   'surely--',
#   'door',
#   'unchained?',
#   '',
#   'passage',
#   'was',
#   'black;',
#   'but',
#   'he',
#   'risked',
#   'it--',
#   'death',
#   'darkness--',
#   'or',
#   'her',
#   'hot',
#   'arms--',
#   '_love--love',
#   'me',
#   'ah-h-h!_',
#   '',
#   '',
#   '"a',
#   'good',
#   'old',
#   'tune,"',
#   'she',
#   'murmured',
#   '--and',
#   'i',
#   'found',
#   'we',
#   'were',
#   'dancing',
#   '',
#   '',
#   '',
#   ''],
#  ['decoration',
#   '',
#   '',
#   'little',
#   'pagan',
#   'child-god',
#   'plays',
#   'beyond',
#   'far',
#   'horizon',
#   'haze,',
#   'underneath',
#   'twilight',
#   'trees',
#   'he',
#   'blows',
#   'bubble',
#   'breeze,',
#   'which',
#   'is',
#   'borne',
#   'upward',
#   'night',
#   'makes',
#   'heavens',
#   'shine',
#   'with',
#   'light',
#   'but',
#   'soon',
#   'it',
#   'sinks',
#   'earth',
#   'again,',
#   'and,',
#   'hitting',
#   'hills,',
#   'it',
#   'bursts!',
#   'then',
#   'with',
#   'foam',
#   'skies',
#   'are',
#   'splashed',
#   'sprayed;',
#   "that's",
#   'how',
#   'all',
#   'stars',
#   'are',
#   'made',
#   '',
#   '',
#   '',
#   ''],
#  [],
#  ['dos',
#   'passos',
#   'robert',
#   'hillyer',
#   'r',
#   's',
#   'mitchell',
#   'william',
#   'a',
#   'norris',
#   'dudley',
#   'poore',
#   'cuthbert',
#   'wright',
#   '',
#   'illustration',
#   '',
#   'new',
#   'york',
#   'laurence',
#   'j',
#   'gomme',
#   '',
#   '',
#   '',
#   '',
#   'copyright,',
#   '1917,',
#   'by',
#   'laurence',
#   'j',
#   'gomme',
#   '',
#   'vail-ballou',
#   'company',
#   'binghamton',
#   'new',
#   'york',
#   '',
#   '',
#   '',
#   '',
#   'contents',
#   '',
#   '',
#   'page',
#   'e',
#   'estlin',
#   'cummings',
#   '',
#   'thou',
#   'whose',
#   'sword-great',
#   'story',
#   'shine',
#   'deeds',
#   'chorus',
#   'girl',
#   'this',
#   'is',
#   'garden',
#   'it',
#   'may',
#   'not',
#   'always',
#   'be',
#   'so',
#   'crepuscule',
#   'finis',
#   'lover',
#   'speaks',
#   'epitaph',
#   '',
#   '',
#   's',
#   'foster',
#   'damon',
#   '',
#   'incessu',
#   'patuit',
#   'deus',
#   'you',
#   'thought',
#   'i',
#   'had',
#   'forgotten',
#   'venice',
#   'new',
#   'macaber',
#   'war',
#   'calm',
#   'day,',
#   'with',
#   'rollers',
#   'phonograph--tango',
#   'decoration',
#   'threnody',
#   '',
#   '',
#   'j',
#   'r',
#   'dos',
#   'passos',
#   '',
#   'bridge',
#   'salvation',
#   'army',
#   'incarnation',
#   'memory',
#   'saturnalia',
#   '"whan',
#   'that',
#   'aprille"',
#   'night',
#   'piece',
#   '',
#   '',
#   'robert',
#   'hillyer',
#   '',
#   'four',
#   'sonnets',
#   'from',
#   'sonnet-sequence',
#   'sea',
#   'gull',
#   'domesday',
#   'passepied',
#   'by',
#   'scarlatti',
#   'elegy',
#   'antinous',
#   'song',
#   '"my',
#   'peace',
#   'i',
#   'leave',
#   'with',
#   'you"',
#   'recompense',
#   '',
#   '',
#   'r',
#   's',
#   'mitchell',
#   '',
#   'poppy',
#   'song',
#   'love',
#   'dream',
#   'island',
#   'death',
#   'from',
#   'arabian',
#   'nights',
#   'threnody',
#   'helen',
#   'largo',
#   'lazarus',
#   'crucifix',
#   'neith',
#   'farewell',
#   '',
#   '',
#   'william',
#   'a',
#   'norris',
#   '',
#   'too',
#   'much',
#   'song',
#   'wherever',
#   'my',
#   'dreams',
#   'go',
#   'out',
#   'littleness',
#   'nahant',
#   'qui',
#   'sub',
#   'luna',
#   'errant',
#   'across',
#   'taut',
#   'strings',
#   'escape',
#   'on',
#   'street',
#   'corner',
#   'sea-burial',
#   '',
#   '',
#   'dudley',
#   'poore',
#   '',
#   'renaissance',
#   'picture',
#   "philosopher's",
#   'garden',
#   'tree',
#   'stars',
#   'after',
#   'rain',
#   'cor',
#   'cordium',
#   'withered',
#   'leaf,',
#   'faded',
#   'flower',
#   'be',
#   'mine',
#   '',
#   '',
#   'cuthbert',
#   'wright',
#   '',
#   'end',
#   'it',
#   'new',
#   'platonist',
#   'room',
#   'over',
#   'river',
#   'fiddler',
#   "falstaff's",
#   'page',
#   'dull',
#   'sunday',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'e',
#   'estlin',
#   'cummings',
#   '',
#   '',
#   '',
#   '',
#   'thou',
#   'whose',
#   'sword-great',
#   'story',
#   'shine',
#   'deeds',
#   '',
#   '',
#   'thou',
#   'whose',
#   'sword-great',
#   'story',
#   'shine',
#   'deeds',
#   'history',
#   'her',
#   'heroes,',
#   'sounds',
#   'tread',
#   'those',
#   'vast',
#   'armies',
#   'marching',
#   'dead,',
#   'with',
#   'standards',
#   'neighing',
#   'great',
#   'steeds',
#   'moving',
#   'war',
#   'across',
#   'smiling',
#   'meads;',
#   'thou',
#   'by',
#   'whose',
#   'page',
#   'we',
#   'break',
#   'precious',
#   'bread',
#   'dear',
#   'communion',
#   'with',
#   'past,',
#   'wed',
#   'valor,',
#   'battle',
#   'with',
#   'heroic',
#   'breeds;',
#   '',
#   'thou,',
#   'froissart,',
#   'that',
#   'thou',
#   'didst',
#   'love',
#   'pen',
#   'while',
#   'others',
#   'wrote',
#   'steel,',
#   'accept',
#   'all',
#   'praise',
#   'after',
#   'ages,',
#   'hungering',
#   'days',
#   'whom',
#   'old',
#   'glories',
#   'move,',
#   'old',
#   'trumpets',
#   'cry;',
#   'who',
#   "gav'st",
#   'as',
#   'one',
#   'those',
#   'immortal',
#   'men',
#   'his',
#   'life',
#   'that',
#   'his',
#   'fair',
#   'city',
#   'might',
#   'not',
#   'die',
#   '',
#   '',
#   '',
#   '',
#   'chorus',
#   'girl',
#   '',
#   '',
#   'when',
#   'thou',
#   'hast',
#   'taken',
#   'thy',
#   'last',
#   'applause,',
#   'when',
#   'final',
#   'curtain',
#   'strikes',
#   'world',
#   'away,',
#   'leaving',
#   'shadowy',
#   'silence',
#   'dismay',
#   'that',
#   'stage',
#   'which',
#   'shall',
#   'not',
#   'know',
#   'thy',
#   'smile',
#   'again,',
#   'lingering',
#   'little',
#   'while',
#   'i',
#   'see',
#   'thee',
#   'then',
#   'ponder',
#   'tinsel',
#   'part',
#   'they',
#   'let',
#   'thee',
#   'play;',
#   'i',
#   'see',
#   'red',
#   'mouth',
#   'tarnished,',
#   'face',
#   'grey,',
#   'smileless',
#   'silent',
#   'eyes',
#   'magdalen',
#   '',
#   'lights',
#   'have',
#   'laughed',
#   'their',
#   'last;',
#   'without,',
#   'street',
#   'darkling,',
#   'awaiteth',
#   'her',
#   'whose',
#   'feet',
#   'have',
#   'trod',
#   'silly',
#   'souls',
#   'men',
#   'golden',
#   'dust',
#   'she',
#   'pauses,',
#   'on',
#   'lintel',
#   'defeat,',
#   'her',
#   'heart',
#   'breaks',
#   'smile--and',
#   'she',
#   'is',
#   'lust',
#   '',
#   'mine',
#   'also,',
#   'little',
#   'painted',
#   'poem',
#   'god',
#   '',
#   'this',
#   'is',
#   'garden:',
#   'colors',
#   'come',
#   'go,',
#   'frail',
#   'azures',
#   'fluttering',
#   'from',
#   "night's",
#   'outer',
#   'wing,',
#   'strong',
#   'silent',
#   'greens',
#   'serenely',
#   'lingering,',
#   'absolute',
#   'lights',
#   'like',
#   'baths',
#   'golden',
#   'snow',
#   'this',
#   'is',
#   'garden:',
#   'pursed',
#   'lips',
#   'do',
#   'blow',
#   'upon',
#   'cool',
#   'flutes',
#   'within',
#   'wide',
#   'glooms,',
#   'sing,',
#   'harps',
#   'celestial',
#   'quivering',
#   'string,',
#   'invisible',
#   'faces',
#   'hauntingly',
#   'slow',
#   '',
#   'this',
#   'is',
#   'garden',
#   'time',
#   'shall',
#   'surely',
#   'reap,',
#   'on',
#   "death's",
#   'blade',
#   'lie',
#   'many',
#   'flower',
#   'curled,',
#   'other',
#   'lands',
#   'where',
#   'other',
#   'songs',
#   'be',
#   'sung;',
#   'yet',
#   'stand',
#   'they',
#   'here',
#   'enraptured,',
#   'as',
#   'among',
#   'slow',
#   'deep',
#   'trees',
#   'perpetual',
#   'sleep',
#   'some',
#   'silver-fingered',
#   'fountain',
#   'steals',
#   'world',
#   '',
#   'it',
#   'may',
#   'not',
#   'always',
#   'be',
#   'so;',
#   'i',
#   'say',
#   'that',
#   'if',
#   'your',
#   'lips,',
#   'which',
#   'i',
#   'have',
#   'loved,',
#   'should',
#   'touch',
#   "another's,",
#   'your',
#   'dear',
#   'strong',
#   'fingers',
#   'clutch',
#   'his',
#   'heart,',
#   'as',
#   'mine',
#   'time',
#   'not',
#   'far',
#   'away;',
#   'if',
#   'on',
#   "another's",
#   'face',
#   'your',
#   'sweet',
#   'hair',
#   'lay',
#   'such',
#   'silence',
#   'as',
#   'i',
#   'know,',
#   'or',
#   'such',
#   'great',
#   'writhing',
#   'words',
#   'as,',
#   'uttering',
#   'overmuch,',
#   'stand',
#   'helplessly',
#   'before',
#   'spirit',
#   'at',
#   'bay;',
#   '',
#   'if',
#   'this',
#   'should',
#   'be,',
#   'i',
#   'say',
#   'if',
#   'this',
#   'should',
#   'be--',
#   'you',
#   'my',
#   'heart,',
#   'send',
#   'me',
#   'little',
#   'word;',
#   'that',
#   'i',
#   'may',
#   'go',
#   'unto',
#   'him,',
#   'take',
#   'his',
#   'hands,',
#   'saying,',
#   'accept',
#   'all',
#   'happiness',
#   'from',
#   'me',
#   'then',
#   'shall',
#   'i',
#   'turn',
#   'my',
#   'face,',
#   'hear',
#   'one',
#   'bird',
#   'sing',
#   'terribly',
#   'afar',
#   'lost',
#   'lands',
#   '',
#   '',
#   '',
#   '',
#   'crepuscule',
#   '',
#   '',
#   'i',
#   'will',
#   'wade',
#   'out',
#   'till',
#   'my',
#   'thighs',
#   'are',
#   'steeped',
#   'burn-',
#   'ing',
#   'flowers',
#   'i',
#   'will',
#   'take',
#   'sun',
#   'my',
#   'mouth',
#   'leap',
#   'into',
#   'ripe',
#   'air',
#   'alive',
#   'with',
#   'closed',
#   'eyes',
#   'dash',
#   'against',
#   'darkness',
#   'sleeping',
#   'curves',
#   'my',
#   'body',
#   'shall',
#   'enter',
#   'fingers',
#   'smooth',
#   'mastery',
#   'with',
#   'chasteness',
#   'sea-girls',
#   'will',
#   'i',
#   'complete',
#   'mystery',
#   'my',
#   'flesh',
#   'i',
#   'will',
#   'rise',
#   'after',
#   'thousand',
#   'years',
#   'lipping',
#   'flowers',
#   'set',
#   'my',
#   'teeth',
#   'silver',
#   'moon',
#   '',
#   '',
#   '',
#   '',
#   'finis',
#   '',
#   '',
#   'over',
#   'silent',
#   'waters',
#   'day',
#   'descending',
#   'night',
#   'ascending',
#   'floods',
#   'gentle',
#   'glory',
#   'sunset',
#   'golden',
#   'greeting',
#   'splendidly',
#   'westward',
#   'as',
#   'pale',
#   'twilight',
#   'trem-',
#   'bles',
#   'into',
#   'darkness',
#   'comes',
#   'last',
#   "light's",
#   'gracious',
#   'exhortation',
#   'lifting',
#   'up',
#   'peace',
#   'so',
#   'when',
#   'life',
#   'shall',
#   'falter',
#   'standing',
#   'on',
#   'shores',
#   'the',
#   'eternal',
#   'god',
#   'may',
#   'i',
#   'behold',
#   'my',
#   'sunset',
#   'flooding',
#   'over',
#   'silent',
#   'waters',
#   '',
#   '',
#   '',
#   '',
#   'lover',
#   'speaks',
#   '',
#   '',
#   'your',
#   'little',
#   'voice',
#   'over',
#   'wires',
#   'came',
#   'leaping',
#   'i',
#   'felt',
#   'suddenly',
#   'dizzy',
#   'with',
#   'jostling',
#   'shouting',
#   'merry',
#   'flowers',
#   'wee',
#   'skipping',
#   'high-heeled',
#   'flames',
#   'courtesied',
#   'before',
#   'my',
#   'eyes',
#   'or',
#   'twinkling',
#   'over',
#   'my',
#   'side',
#   'looked',
#   'up',
#   'with',
#   'impertinently',
#   'exquisite',
#   'faces',
#   'floating',
#   'hands',
#   'were',
#   'laid',
#   'upon',
#   'me',
#   'i',
#   'was',
#   'whirled',
#   'tossed',
#   'into',
#   'delicious',
#   'dancing',
#   'up',
#   'up',
#   'with',
#   'pale',
#   'important',
#   'stars',
#   'humorous',
#   'moon',
#   'dear',
#   'girl',
#   'how',
#   'i',
#   'was',
#   'crazy',
#   'how',
#   'i',
#   'cried',
#   'when',
#   'i',
#   'heard',
#   'over',
#   'time',
#   'tide',
#   'death',
#   'leaping',
#   'sweetly',
#   'your',
#   'voice',
#   '',
#   '',
#   '',
#   '',
#   'epitaph',
#   '',
#   '',
#   'tumbling-hair',
#   'picker',
#   'buttercups',
#   'violets',
#   'dandelions',
#   'big',
#   'bullying',
#   'daisies',
#   'through',
#   'field',
#   'wonderful',
#   'with',
#   'eyes',
#   'little',
#   'sorry',
#   'another',
#   'comes',
#   'also',
#   'picking',
#   'flowers',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   's',
#   'foster',
#   'damon',
#   '',
#   '',
#   '',
#   '',
#   'incessu',
#   'patuit',
#   'deus',
#   '',
#   '',
#   'little',
#   'clattering',
#   'stones',
#   'along',
#   'street',
#   'dance',
#   'with',
#   'each',
#   'other',
#   'round',
#   'my',
#   'swimming',
#   'feet;',
#   'street',
#   'itself,',
#   'as',
#   'some',
#   'crazy',
#   'dream,',
#   'streaks',
#   'past,',
#   'half-perceived',
#   'material',
#   'stream',
#   '',
#   'brighter',
#   'than',
#   'early',
#   "dawn's",
#   'most',
#   'brilliant',
#   'dye',
#   'are',
#   'blown',
#   'clear',
#   'bands',
#   'color',
#   'through',
#   'sky,',
#   'that',
#   'swirl',
#   'sweep',
#   'meet,',
#   'break',
#   'foam',
#   'like',
#   'rainbow',
#   'veils',
#   'upon',
#   "bubble's",
#   'dome',
#   '',
#   'yours',
#   'are',
#   'songs',
#   'that',
#   'burst',
#   'about',
#   'my',
#   'ears,',
#   'or',
#   'blow',
#   'away',
#   'as',
#   'many-colored',
#   'spheres',
#   '',
#   'you',
#   'are',
#   'star',
#   'that',
#   'made',
#   'skies',
#   'all',
#   'bright,',
#   'yet',
#   'tore',
#   'itself',
#   'away',
#   'flaming',
#   'flight;',
#   'you',
#   'are',
#   'tree',
#   'that',
#   'suddenly',
#   'awoke;',
#   'you',
#   'are',
#   'rose',
#   'that',
#   'came',
#   'life',
#   'spoke',
#   '',
#   'guided',
#   'by',
#   'you,',
#   'how',
#   'we',
#   'might',
#   'stroll',
#   'towards',
#   'death,',
#   'our',
#   'only',
#   'music',
#   'one',
#   "another's",
#   'breath,',
#   'through',
#   'gardens',
#   'intimate',
#   'with',
#   'hollyhocks,',
#   'where',
#   'silent',
#   'poppies',
#   'burn',
#   'between',
#   'rocks,',
#   'by',
#   'pools',
#   'where',
#   'birches',
#   'bend',
#   'confidants',
#   'above',
#   'green',
#   'waters',
#   'scummed',
#   'with',
#   'lily-plants',
#   '',
#   'there',
#   'we',
#   'might',
#   'wander,',
#   'you',
#   'i',
#   'alone,',
#   'through',
#   'gardens',
#   'filled',
#   'with',
#   'marble',
#   'seats',
#   'moss-grown,',
#   'fountains--water-threads',
#   'that',
#   'winds',
#   'disperse--',
#   'while',
#   'spray',
#   'birds',
#   'sit',
#   'converse',
#   '',
#   'when',
#   'fireflies',
#   'mix',
#   'their',
#   'circling',
#   'glow',
#   'through',
#   'dark',
#   'plants,',
#   'then',
#   'gently',
#   'might',
#   'i',
#   'know',
#   'your',
#   'lips,',
#   'light',
#   'as',
#   'wings',
#   'dragon-flies',
#   '',
#   '--merely',
#   'dreams,',
#   'fluttering',
#   'my',
#   'eyes',
#   '',
#   '',
#   '',
#   '',
#   'you',
#   'thought',
#   'i',
#   'had',
#   'forgotten',
#   '',
#   '',
#   'you',
#   'thought',
#   'i',
#   'had',
#   'forgotten',
#   'well,',
#   'i',
#   'had!',
#   'although',
#   'i',
#   'never',
#   'guessed',
#   'i',
#   'could',
#   'forget',
#   'those',
#   'few',
#   'great',
#   'moments',
#   'when',
#   'we',
#   'both',
#   'went',
#   'mad',
#   '',
#   '',
#   'other',
#   'day',
#   'at',
#   "someone's",
#   'tea',
#   'we',
#   'met,',
#   'smiling',
#   'gayly,',
#   'bowed,',
#   'went',
#   'our',
#   'several',
#   'ways,',
#   'complacent',
#   'with',
#   'successful',
#   'coldness.--yet',
#   '',
#   'suddenly',
#   'i',
#   'was',
#   'back',
#   'old',
#   'days',
#   'before',
#   'you',
#   'felt',
#   'we',
#   'ought',
#   'drift',
#   'apart',
#   'it',
#   'was',
#   'some',
#   'trick--the',
#   'way',
#   'your',
#   'eyebrows',
#   'raise,',
#   '',
#   'your',
#   'hands--some',
#   'vivid',
#   'trifle',
#   'with',
#   'start',
#   'then',
#   'i',
#   'remembered',
#   'how',
#   'i',
#   'lived',
#   'alone,',
#   'writing',
#   'bad',
#   'poems',
#   'eating',
#   'out',
#   'my',
#   'heart',
#   '',
#   'all',
#   'your',
#   'beauty.--how',
#   'time',
#   'has',
#   'flown!',
#   '',
#   '',
#   '',
#   '',
#   'venice',
#   '',
#   '',
#   'sunset',
#   'glowing',
#   'crimson',
#   'gold,',
#   'she',
#   'lies,',
#   'glory',
#   'world,',
#   'beached',
#   "king's",
#   'galley,',
#   'whose',
#   'sails',
#   'are',
#   'furled,',
#   'who',
#   'is',
#   'hung',
#   'with',
#   'tapestries',
#   'rich',
#   'old',
#   '',
#   'beautiful',
#   'as',
#   'woman',
#   'is',
#   'she,',
#   'woman',
#   'whose',
#   'autumn',
#   'life',
#   'is',
#   'here,',
#   'proud',
#   'calm',
#   'at',
#   'end',
#   'year',
#   'with',
#   'grace',
#   'that',
#   'now',
#   'is',
#   'majesty',
#   '',
#   'sleeping',
#   'waters',
#   'bathe',
#   'her',
#   'sides,',
#   'warm,',
#   'blue',
#   'streams',
#   'adrian',
#   'sea;',
#   'she',
#   'dreams',
#   'drowses',
#   'languorously,',
#   'swayed',
#   'swaying',
#   'tides',
#   '',
#   'she',
#   'is',
#   'goddess',
#   'left',
#   'us,',
#   'veiled',
#   'with',
#   'softening',
#   'veils',
#   'time;',
#   'her',
#   'blue-veined',
#   'breasts',
#   'are',
#   'now',
#   'sublime,',
#   'her',
#   'moulded',
#   'torso',
#   'glorious',
#   '',
#   'pity',
#   'that',
#   'we',
#   'must',
#   'come',
#   'go--!',
#   'while',
#   'old',
#   'gold',
#   'marble',
#   'stays,',
#   'forever',
#   'gleaming',
#   'its',
#   'soft',
#   'strong',
#   'blaze,',
#   'calm',
#   'early',
#   'evening',
#   'glow',
#   '',
#   'still',
#   'sensitive',
#   'silhouettes',
#   'gondolas',
#   'pass',
#   'leave',
#   'no',
#   'track,',
#   'light',
#   'on',
#   'tides',
#   'as',
#   'lilies,',
#   'black',
#   'rippling',
#   'waters',
#   'long',
#   'sunsets',
#   '',
#   '',
#   '',
#   '',
#   'new',
#   'macaber',
#   '',
#   '',
#   'pleasant',
#   'graveyard',
#   'my',
#   'soul',
#   'with',
#   'sentimental',
#   'cypress',
#   'trees',
#   'flowers',
#   'is',
#   'filled,',
#   'that',
#   'i',
#   'may',
#   'stroll',
#   'meditation,',
#   'at',
#   'my',
#   'ease',
#   '',
#   'little',
#   'marble',
#   'stones',
#   'are',
#   'lost',
#   'flowers',
#   'surging',
#   'from',
#   'dead;',
#   'nor',
#   'is',
#   'there',
#   'any',
#   'mournful',
#   'ghost',
#   'wail',
#   'until',
#   'night',
#   'is',
#   'sped',
#   '',
#   'while',
#   'night',
#   'rustles',
#   'through',
#   'trees,',
#   'dragging',
#   'stars',
#   'along,',
#   'i',
#   'know',
#   'moon',
#   'is',
#   'rising',
#   'on',
#   'breeze,',
#   'quivering',
#   'as',
#   "river's",
#   'flow',
#   '',
#   'ah!',
#   'that',
#   'moon',
#   'silver',
#   'sheen!',
#   'it',
#   'is',
#   'my',
#   'heart',
#   'hung',
#   'sky;',
#   'no',
#   'clouds',
#   'ever',
#   'float',
#   'between',
#   'grave-flowers',
#   'my',
#   'heart',
#   'on',
#   'high',
#   '',
#   'i',
#   'do',
#   'not',
#   'read',
#   'upon',
#   'each',
#   'stone',
#   'name',
#   'that',
#   'once',
#   'was',
#   'carven',
#   'there;',
#   'i',
#   'merely',
#   'note',
#   'new',
#   'blossoms',
#   'blown',
#   'breathe',
#   'perfume',
#   'air',
#   '',
#   'thus',
#   'walk',
#   'i',
#   'through',
#   'my',
#   'wonderland',
#   'while',
#   'all',
#   'evening',
#   'is',
#   'atune,',
#   'beneath',
#   'cypress',
#   'trees',
#   'that',
#   'stand',
#   'like',
#   'candles',
#   'barren',
#   'moon',
#   '',
#   '',
#   '',
#   '',
#   'war',
#   '',
#   '',
#   'music',
#   'beats,',
#   'up',
#   'chasmed',
#   'street,',
#   'then',
#   'flares',
#   'from',
#   'around',
#   'curve;',
#   'cheers',
#   'break',
#   'out',
#   'from',
#   'waving',
#   'crowd:',
#   '--our',
#   'soldiers',
#   'march,',
#   'superb!',
#   'over',
#   'track-lined',
#   'city',
#   'street',
#   'young',
#   'men,',
#   'grinning',
#   'men,',
#   'pass',
#   '',
#   'last',
#   'night',
#   'they',
#   'danced',
#   'that',
#   'very',
#   'tune;',
#   'today',
#   'they',
#   'march',
#   'away;',
#   'tomorrow,',
#   'perhaps',
#   'no',
#   'band',
#   'at',
#   'all,',
#   'or',
#   'band',
#   'beside',
#   'grave',
#   'above,',
#   'long',
#   'blue',
#   'strip',
#   'sky,',
#   'whirling',
#   'pigeons,',
#   'thoughtless',
#   'pigeons,',
#   'pass',
#   '',
#   'another',
#   'band',
#   'beats',
#   'down',
#   'street;',
#   'contending',
#   'rhythms',
#   'clash;',
#   'new',
#   'melodies',
#   'win',
#   'place,',
#   'then',
#   'fade,',
#   'flashing',
#   'legs',
#   'move',
#   'past',
#   'down',
#   'cheering,',
#   'grey-paved',
#   'street',
#   'fringed',
#   'flags,',
#   'erect',
#   'flags,',
#   'pass',
#   '',
#   '',
#   '',
#   '',
#   'calm',
#   'day,',
#   'with',
#   'rollers',
#   '',
#   '',
#   'always',
#   'ships',
#   'that',
#   'move',
#   'mystery,',
#   'on',
#   'dim',
#   'horizon,',
#   'shadow-filled',
#   'sails',
#   'dreams,',
#   'sliding',
#   'over',
#   'blue-grey',
#   'ocean,',
#   'far',
#   'from',
#   'rock-edged',
#   'shore',
#   'where',
#   'willow-green',
#   'waves',
#   'are',
#   'rushing,',
#   'white',
#   'foam-people',
#   'leap,',
#   'stand',
#   'erect',
#   'moment',
#   '',
#   'ho!',
#   'ye',
#   'sails',
#   'that',
#   'seem',
#   'wander',
#   'dream-filled',
#   'meadows,',
#   'say,',
#   'is',
#   'shore',
#   'where',
#   'i',
#   'stand',
#   'only',
#   'field',
#   'struggle,',
#   'or',
#   'are',
#   'ye',
#   'hit',
#   'battered',
#   'out',
#   'there',
#   'by',
#   'waves',
#   'wind-gusts',
#   'as',
#   'ye',
#   'tack',
#   'over',
#   'clashing',
#   'sea',
#   'watery',
#   'echoes?',
#   '',
#   '',
#   '',
#   '',
#   'phonograph--tango',
#   '',
#   '',
#   'old',
#   'dances',
#   'are',
#   'simplified',
#   'their',
#   'yearning,',
#   'bleached',
#   'by',
#   'time',
#   'yet',
#   'from',
#   'one',
#   'black',
#   'disc',
#   'we',
#   'tasted',
#   'again',
#   'bite',
#   'crude',
#   'spanish',
#   'passion',
#   '',
#   '',
#   'he',
#   'had',
#   'got',
#   'into',
#   'her',
#   'courtyard',
#   'she',
#   'was',
#   'alone',
#   'that',
#   'night',
#   'through',
#   'black',
#   'night-rain,',
#   'he',
#   'sang',
#   'her',
#   'window',
#   'bars:',
#   '',
#   '_love',
#   'me,',
#   'love--ah,',
#   'love',
#   'me!_',
#   '_if',
#   'you',
#   'will',
#   'not,',
#   'i',
#   'can',
#   'follow_',
#   '_into',
#   'highest',
#   'mountains;_',
#   '_and',
#   'there,',
#   'wooden',
#   'cabin,_',
#   '_i',
#   'will',
#   'strangle',
#   'you',
#   'your',
#   'lover._',
#   '',
#   '--that',
#   'was',
#   'but',
#   'rustling',
#   'dripping',
#   'plants',
#   'dark',
#   'more',
#   'tightly',
#   'under',
#   'his',
#   'cloak,',
#   'he',
#   'clasped',
#   'his',
#   'guitar',
#   '',
#   '_love,',
#   'ah-h!',
#   'love',
#   'me,',
#   'love',
#   'me!_',
#   '_if',
#   'you',
#   'will',
#   'do',
#   'this,',
#   'i',
#   'can',
#   'buy_',
#   '_a',
#   'fringed',
#   'silk',
#   'scarf',
#   'yellow,_',
#   '_a',
#   'high',
#   'comb',
#   'carved',
#   'tortoise;_',
#   '_then',
#   'we',
#   'will',
#   'dance',
#   'plaza._',
#   '',
#   'she',
#   'was',
#   'alone',
#   'that',
#   'night',
#   'he',
#   'had',
#   'broken',
#   'into',
#   'her',
#   'courtyard',
#   'above',
#   'gurgling',
#   'gutters',
#   'he',
#   'heard--',
#   'surely--',
#   'door',
#   'unchained?',
#   '',
#   'passage',
#   'was',
#   'black;',
#   'but',
#   'he',
#   'risked',
#   'it--',
#   'death',
#   'darkness--',
#   'or',
#   'her',
#   'hot',
#   'arms--',
#   '_love--love',
#   'me',
#   'ah-h-h!_',
#   '',
#   '',
#   '"a',
#   'good',
#   'old',
#   'tune,"',
#   'she',
#   'murmured',
#   '--and',
#   'i',
#   'found',
#   'we',
#   'were',
#   'dancing',
#   '',
#   '',
#   '',
#   '',
#   'decoration',
#   '',
#   '',
#   'little',
#   'pagan',
#   'child-god',
#   'plays',
#   'beyond',
#   'far',
#   'horizon',
#   'haze,',
#   'underneath',
#   'twilight',
#   'trees',
#   'he',
#   'blows',
#   'bubble',
#   'breeze,',
#   'which',
#   'is',
#   'borne',
#   'upward',
#   'night',
#   'makes',
#   'heavens',
#   'shine',
#   'with',
#   'light',
#   'but',
#   'soon',
#   'it',
#   'sinks',
#   'earth',
#   'again,',
#   'and,',
#   'hitting',
#   'hills,',
#   'it',
#   'bursts!',
#   'then',
#   'with',
#   'foam',
#   'skies',
#   'are',
#   'splashed',
#   'sprayed;',
#   "that's",
#   'how',
#   'all',
#   'stars',
#   'are',
#   'made',
#   '',
#   '',
#   '',
#   '',
#   'threnody',
#   '',
#   '',
#   'she',
#   'is',
#   'lain',
#   'with',
#   'high',
#   'things',
#   'with',
#   'low',
#   'she',
#   'lies',
#   'with',
#   'shut',
#   'eyes,',
#   'rocked',
#   'eternal',
#   'flow',
#   'silence',
#   'evermore',
#   '',
#   'desperately',
#   'immortal,',
#   'she;',
#   'she',
#   'stands',
#   'with',
#   'wide',
#   'hands',
#   'dim',
#   'through',
#   'veil',
#   'eternity,',
#   'behind',
#   'supreme',
#   'door',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'j',
#   'r',
#   'dos',
#   'passos',
#   '',
#   '',
#   '',
#   ''],
#  ['bridge',
#   '',
#   '',
#   'lonely',
#   'bridge',
#   'cuts',
#   'dark',
#   'across',
#   'marsh',
#   'whose',
#   'long',
#   'pools',
#   'glow',
#   'with',
#   'light',
#   'flaring',
#   'summer',
#   'sunset',
#   'at',
#   'this',
#   'end',
#   'limp',
#   'bushes',
#   'overhang,',
#   'palely',
#   'reflected',
#   'amber-colored',
#   'water;',
#   'among',
#   'them',
#   'constant',
#   'banjo-twanging',
#   'frogs,',
#   'shrilling',
#   'toads',
#   'insects',
#   'rises',
#   'falls',
#   'chorus',
#   'rhythmic',
#   'stirring',
#   '',
#   'dark,',
#   'with',
#   'crumbling',
#   'railing',
#   'planks,',
#   'bridge',
#   'leads',
#   'into',
#   'sunset',
#   'across',
#   'it',
#   'many',
#   'lonely',
#   'figures,',
#   'their',
#   'eyes',
#   'a-flare',
#   'with',
#   'sunset,',
#   'their',
#   'faces',
#   'glowing',
#   'with',
#   'its',
#   'colors,',
#   'tramp',
#   'past',
#   'me',
#   'through',
#   'evening',
#   '',
#   'i',
#   'am',
#   'tired',
#   'sitting',
#   'quiet',
#   'among',
#   'bushes',
#   'shore,',
#   'while',
#   'dark',
#   'bridge',
#   'stretches',
#   'onward,',
#   'long',
#   'pools',
#   'gleam',
#   'with',
#   'light;',
#   'i',
#   'am',
#   'tired',
#   'shrilling',
#   'insects',
#   'croaking',
#   'frogs',
#   'rushes,',
#   'wild',
#   'rice',
#   'marsh-pools',
#   'waves',
#   'its',
#   'beckoning',
#   'streamers',
#   'wind,',
#   'red',
#   'sky-glory',
#   'fades',
#   '',
#   '',
#   '',
#   ''],
#  ['salvation',
#   'army',
#   '',
#   '',
#   'drum',
#   'pounds',
#   'out',
#   'hymn,',
#   'loud',
#   'with',
#   'gaudy',
#   'angels,',
#   'tinsel',
#   'cherubim,',
#   'drown',
#   'fanfare',
#   'street,',
#   'with',
#   'exultant',
#   'lilting',
#   'beat,',
#   'mingle',
#   'endless',
#   'rumble',
#   'carts,',
#   'scrape',
#   'feet,',
#   'noise',
#   'marts',
#   'dinning',
#   'market',
#   'stalls,',
#   'where',
#   'women',
#   'shout',
#   'their',
#   'wares,',
#   'meat',
#   'hangs',
#   'out--',
#   'grotesque,',
#   'distorted',
#   'by',
#   'gas',
#   "flare's",
#   'light--',
#   'into',
#   'one',
#   'sacred',
#   'rhythm',
#   "devil's",
#   'spite',
#   '',
#   "woman's",
#   'thin,',
#   'raucous',
#   'voice',
#   'carries',
#   'tune,',
#   'bids',
#   'men',
#   'rejoice,',
#   'bathe',
#   "god's",
#   'mercy,',
#   'draw',
#   'near',
#   'learn',
# ...
#   'him',
#   'there',
#   '',
#   'forever',
#   'through',
#   'groves',
#   'glades',
#   'kind',
#   'thoughts',
#   'went',
#   'softly',
#   'fro,',
#   'memories',
#   'like',
#   'white-footed',
#   'maids',
#   'with',
#   'gentle',
#   'tread',
#   'would',
#   'come',
#   'go',
#   'among',
#   'ever-garrulous',
#   'trees',
#   'through',
#   'branches',
#   'overhead',
#   'i',
#   'know',
#   'not',
#   'what',
#   'sweet',
#   'spirits',
#   'strayed,',
#   'or',
#   'what',
#   'commandant',
#   'spirit',
#   'led',
#   'their',
#   'mazy',
#   'dances,',
#   'but',
#   'one',
#   'played',
#   'so',
#   'deftly',
#   'on',
#   'psaltery',
#   'that',
#   'they',
#   'joy',
#   'must',
#   'needs',
#   'keep',
#   'singing;',
#   'all',
#   'chambers',
#   "love's",
#   'house',
#   'with',
#   'that',
#   'sweet',
#   'minstrelsy',
#   'were',
#   'ringing',
#   'faces',
#   'windows',
#   'came,',
#   'tears',
#   'happy',
#   'eyelids',
#   'started,',
#   'feeling,',
#   'as',
#   'by',
#   'sudden',
#   'flame,',
#   'their',
#   'cares',
#   'their',
#   'sad',
#   'hearts',
#   'disparted,',
#   'each',
#   'old',
#   'clinging',
#   'sorrow',
#   'dead',
#   '',
#   'all',
#   'who',
#   'ever',
#   'guested',
#   'there',
#   'each',
#   'other,',
#   'murmuring,',
#   'said:',
#   '"in',
#   'this',
#   'heart',
#   'breathes',
#   'purer',
#   'air,',
#   'thoughts',
#   'that',
#   'move',
#   'across',
#   'this',
#   'sky',
#   'have',
#   'had',
#   'more',
#   'mysterious',
#   'birth,',
#   'are',
#   'lovelier,',
#   'float',
#   'more',
#   'statelily',
#   'than',
#   'clouds',
#   'across',
#   'sky',
#   'earth."',
#   'all',
#   'guests',
#   'within',
#   'that',
#   "heart's",
#   'deep',
#   'wood,',
#   'all',
#   'friends',
#   'together',
#   'that',
#   'house,',
#   'high',
#   'converse',
#   'held',
#   'with',
#   'an',
#   'aerial',
#   'brood,',
#   'with',
#   'spirit-folk',
#   'kept',
#   'delicate',
#   'carouse;',
#   'none',
#   'ever',
#   'turned',
#   'ungreeted',
#   'from',
#   'that',
#   'door',
#   'sorrow',
#   'himself',
#   'was',
#   'guest',
#   'weary',
#   'while,',
#   '',
#   'but',
#   'yesterday',
#   'when',
#   'i',
#   'passed',
#   'by',
#   'once',
#   'more,',
#   'met',
#   'me',
#   'no',
#   'welcoming',
#   'smile,',
#   'nor',
#   'any',
#   'breath',
#   'unwavering',
#   'branch',
#   'stir,',
#   'silent',
#   'each',
#   'glad',
#   'aerial',
#   'chorister;',
#   'three',
#   'drowsy',
#   'poppies',
#   'brooded',
#   'by',
#   'wall,',
#   'lonely',
#   'tall',
#   '',
#   'then,',
#   'as',
#   'i',
#   'leaned',
#   'above',
#   'their',
#   'crimson',
#   'bloom,',
#   'flower',
#   'day',
#   'grew',
#   'old',
#   'withered,',
#   'night',
#   'with',
#   'sigh',
#   'sat',
#   'down',
#   'beside',
#   'her',
#   'loom',
#   'winding',
#   'her',
#   'shuttle',
#   'with',
#   'silver',
#   'thread',
#   'suddenly',
#   'from',
#   'starlit',
#   'plains',
#   'air',
#   'ethereal',
#   'tumult,',
#   'airy',
#   'tempest',
#   'blew,',
#   'immortal',
#   'music',
#   'showering',
#   'everywhere,',
#   'flashed',
#   'earth',
#   'an',
#   'harmonious',
#   'dew,',
#   'leaped',
#   'jubilant',
#   'from',
#   'cloud',
#   'craggy',
#   'cloud,',
#   'binding',
#   'moon',
#   'melodious',
#   'chain,',
#   'storming',
#   'troubled',
#   'stars,',
#   'luminous',
#   'crowd,',
#   'dropping',
#   'fiery',
#   'streaks',
#   'earth',
#   'again',
#   'from',
#   'out',
#   'windows',
#   "god's",
#   'house',
#   'faint',
#   'as',
#   'far-echoing',
#   'wave,',
#   'angels,',
#   'bending',
#   'their',
#   'calm',
#   'brows,',
#   'song',
#   'song',
#   'answer',
#   'gave;',
#   'faster',
#   'than',
#   'falcon',
#   'flies,',
#   'thronging',
#   'spirits',
#   'cluster',
#   'passed',
#   'before',
#   'my',
#   'dazzled',
#   'eyes,',
#   'shedding',
#   'an',
#   'aerial',
#   'lustre,',
#   'burning',
#   'with',
#   'translucent',
#   'fire,',
#   'shaking',
#   'from',
#   'their',
#   'dewy',
#   'wings',
#   'wild,',
#   'ineffable',
#   'desire',
#   'starry',
#   'immortal',
#   'things,',
#   'torturing',
#   'with',
#   'delicious',
#   'pain',
#   'past',
#   'telling',
#   'sweet,',
#   'bewildered',
#   'heart,',
#   'piercing',
#   'poor',
#   'mortal',
#   'brain',
#   'with',
#   'beauty,',
#   'keen',
#   'fiery',
#   'dart',
#   'ah!',
#   'even',
#   'as',
#   'an',
#   'oracle',
#   'whose',
#   'soul',
#   'god',
#   'has',
#   'breathed',
#   'upon,',
#   'beauteousness',
#   'unbearable',
#   'possessed',
#   'me',
#   'so',
#   'all',
#   'strength',
#   'was',
#   'gone',
#   'smitten',
#   'by',
#   'barbed',
#   'joy,',
#   'my',
#   'sense',
#   'with',
#   'rapturous',
#   'pain',
#   'grew',
#   'dim,',
#   'joy',
#   'pierced',
#   'me',
#   'as',
#   'it',
#   'would',
#   'destroy',
#   'still',
#   'higher',
#   'rose',
#   'celestial',
#   'hymn',
#   'then',
#   'all',
#   'that',
#   'starry',
#   'throng',
#   'that',
#   'streamed',
#   'toward',
#   'upper',
#   'sky,',
#   'one',
#   'spirit',
#   'darted',
#   'down',
#   'again,',
#   'stood',
#   'upon',
#   'bough',
#   'near',
#   'by',
#   '"even',
#   'i',
#   'unsealed',
#   'thy',
#   'sight,"',
#   'he',
#   'said',
#   'alas,',
#   'that',
#   'shape',
#   'i',
#   'did',
#   'not',
#   'know,',
#   'he',
#   'was',
#   'so',
#   'transfigured,',
#   'so',
#   'circled',
#   'by',
#   'unearthly',
#   'glow',
#   'his',
#   'pulsating',
#   'aureole;',
#   'i',
#   'who',
#   'so',
#   'well',
#   'flesh',
#   'had',
#   'known',
#   'i',
#   'did',
#   'not',
#   'know',
#   'soul',
#   'with',
#   'troubled',
#   'eyes',
#   'he',
#   'bended',
#   'down,',
#   'all',
#   'about',
#   'me',
#   'where',
#   'i',
#   'stood',
#   'every',
#   'blossom,',
#   'every',
#   'tree,',
#   'all',
#   'branches',
#   'that',
#   'wood',
#   'were',
#   'trembling',
#   'their',
#   'ecstasy',
#   'they',
#   'knew',
#   'ere',
#   'i',
#   'had',
#   'half',
#   'divined',
#   'but',
#   'at',
#   'his',
#   'voice',
#   'old',
#   'dreams',
#   'awoke',
#   'dusty',
#   'chambers',
#   'mind,',
#   'when',
#   'again',
#   'he',
#   'softly',
#   'spoke',
#   'with',
#   'sudden',
#   'tears',
#   'mine',
#   'eyes',
#   'were',
#   'wet',
#   'lowlier',
#   'still',
#   'he',
#   'bent',
#   'his',
#   'head:',
#   '"dost',
#   'thou,',
#   'dear',
#   'friend,',
#   'not',
#   'know',
#   'me',
#   'yet?"',
#   '"yes,',
#   'i',
#   'know',
#   'thy',
#   'voice,"',
#   'i',
#   'said',
#   '"dear',
#   'phantom,',
#   'this',
#   'immortal',
#   'guise,',
#   'this',
#   'disembodied',
#   'self',
#   'thine,',
#   'hath',
#   'dazed',
#   'mine',
#   'unacquainted',
#   'eyes',
#   'thou',
#   'dweller',
#   'on',
#   'steps',
#   'divine,',
#   'thou',
#   'image',
#   "god's",
#   'desire,',
#   'thou',
#   'spark',
#   'celestial',
#   'flame',
#   'art',
#   'fashioned',
#   'out',
#   'wind',
#   'fire',
#   'elements',
#   'without',
#   'name;',
#   'what',
#   'sacred',
#   'fingers',
#   'mingled',
#   'them',
#   'trembled',
#   'with',
#   "god's",
#   'delight?',
#   'thy',
#   'body',
#   'is',
#   'burning',
#   'gem,',
#   'thy',
#   'limbs',
#   'are',
#   'chrysolite',
#   'glory',
#   'hangs',
#   'about',
#   'thy',
#   'head',
#   'thou',
#   'thine',
#   'immortal',
#   'lot',
#   "heaven's",
#   'own',
#   'light',
#   'art',
#   'garmented',
#   'i',
#   'know',
#   'thee,',
#   'yet',
#   'i',
#   'know',
#   'thee',
#   'not."',
#   'then',
#   'he,',
#   'with',
#   'shining',
#   'eyes',
#   'half',
#   'shut,',
#   'radiantly',
#   'standing',
#   'there:',
#   '"i',
#   'did',
#   'but',
#   'change',
#   'my',
#   'leafy',
#   'hut',
#   'mansion',
#   'air,',
#   'eerie',
#   'wood,',
#   'enchanted',
#   'ground,',
#   'dim,',
#   'bird-haunted',
#   'glades',
#   'we',
#   'trod,',
#   'grew',
#   'all',
#   'untuneful',
#   'when',
#   'i',
#   'found',
#   'dwelling',
#   'heart',
#   'god',
#   'i',
#   'latched',
#   'gate',
#   'at',
#   'dawn',
#   'day,',
#   'i',
#   'planted',
#   'poppies',
#   'by',
#   'door,',
#   'his',
#   'retreats',
#   'i',
#   'came',
#   'away',
#   'i',
#   'shall',
#   'wander',
#   'thence',
#   'no',
#   'more',
#   'windy',
#   'heights',
#   'are',
#   'all',
#   'my',
#   'love,',
#   'spheral',
#   'lights,',
#   'spheral',
#   'chimes,',
#   'trailing',
#   'fires,',
#   'hosts',
#   'that',
#   'move',
#   'concourse',
#   'through',
#   'sidereal',
#   'climes;',
#   'i',
#   'troop',
#   'with',
#   'celestial',
#   'choirs;',
#   'we',
#   'have',
#   'not',
#   'any',
#   'wish',
#   'be',
#   'sad',
#   'pilgrims,',
#   'torn',
#   'by',
#   'sad',
#   'desires,',
#   'wayfarers',
#   'mortality',
#   'husk',
#   'flesh',
#   'we',
#   'have',
#   'put',
#   'by;',
#   'dark',
#   'seeds',
#   'planted',
#   'earth',
#   'have',
#   'blossomed',
#   'upper',
#   'sky,',
#   'airy',
#   'gardens',
#   'have',
#   'new',
#   'birth."',
#   '',
#   'there',
#   'did',
#   'he',
#   'make',
#   'an',
#   'end,',
#   'o',
#   'those',
#   'spirits,',
#   'singing,',
#   'darted',
#   'by',
#   'again,',
#   'at',
#   'showering',
#   'sound',
#   'he',
#   'trembled',
#   'so',
#   'i',
#   'saw',
#   'his',
#   'earthly',
#   'dalliance',
#   'gave',
#   'him',
#   'pain,',
#   'cried',
#   'sorrow,',
#   '"o',
#   'my',
#   'friend,',
#   'farewell!',
#   'now',
#   'from',
#   'luminous,',
#   'paradisal',
#   'bands,',
#   'gabriel,',
#   'israfel,',
#   'ithuriel,',
#   'beckon',
#   'you',
#   'with',
#   'their',
#   'exulting',
#   'hands."',
#   '',
#   '',
#   '',
#   '',
#   'withered',
#   'leaf,',
#   'faded',
#   'flower',
#   'be',
#   'mine',
#   '',
#   '',
#   'withered',
#   'leaf,',
#   'faded',
#   'flower',
#   'be',
#   'broken',
#   'all',
#   'things',
#   'that',
#   'beauty',
#   'day',
#   'have',
#   'passed',
#   'away',
#   'dwell',
#   'illimitable',
#   'wood',
#   'passed',
#   'years',
#   'among',
#   '',
#   'no',
#   'wind',
#   'upon',
#   'their',
#   'beauty',
#   'altar',
#   'with',
#   'flames',
#   'bright',
#   'by',
#   'day,',
#   'by',
#   'from',
#   "time's",
#   'breath',
#   'they',
#   'know',
#   'no',
#   'death,',
#   'but',
#   'grow',
#   'there',
#   '',
#   'he',
#   'who',
#   'too',
#   'much',
#   'hour,',
#   'who',
#   'knows',
#   'not',
#   'with',
#   'what',
#   'an',
#   'hour',
#   "that's",
#   'dead',
#   'is',
#   'who',
#   'with',
#   'he',
#   'cannot',
#   'guess',
#   'with',
#   'how',
#   'great',
#   'love',
#   'i',
#   'praise',
#   'yesterdays',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'cuthbert',
#   'wright',
#   '',
#   '',
#   '',
#   ''],
#  ['end',
#   'it',
#   '',
#   '',
#   'we',
#   'met,',
#   'on',
#   'drive',
#   'touched',
#   'hands,',
#   'pleasant',
#   'i',
#   'said',
#   'sunlight',
#   'upon',
#   'still',
#   'your',
#   'figure',
#   'fading',
#   'dusty',
#   'red',
#   'i',
#   'watched',
#   'awhile,',
#   'then',
#   'turned',
#   'with',
#   'casual',
#   'face',
#   'where',
#   'torrent',
#   'down',
#   'no',
#   'human',
#   'voice',
#   'troubled',
#   'lovely',
#   'place,',
#   'only',
#   'fall',
#   'music',
#   'made',
#   '',
#   'time',
#   'i',
#   'lay',
#   'with',
#   'stare',
#   'keen',
#   'on',
#   'lawn,',
#   'thought',
#   'on',
#   'shrines',
#   'all',
#   'voiceless',
#   'now',
#   'their',
#   'till',
#   'with',
#   'hoarse',
#   'cry',
#   'train',
#   'that',
#   'you',
#   'were',
#   'on',
#   'empty',
#   'air',
#   '',
#   '',
#   'then',
#   'i',
#   'awoke',
#   'knew',
#   'that',
#   'you',
#   'were',
#   'gone',
#   '',
#   '',
#   '',
#   ''],
#  ['new',
#   'platonist',
#   '',
#   '',
#   '',
#   'our',
#   'as',
#   'flowers',
#   'fall',
#   'singing',
#   'hath',
#   'an',
#   'no',
#   'man',
#   'his',
#   'own',
#   'soul',
#   'may',
#   'trust,',
#   'nor',
#   'kind',
#   'arms',
#   'his',
#   'yet',
#   'have',
#   'i',
#   'by',
#   'lonely',
#   'tree,',
#   'bright',
#   'baths',
#   'immortality',
#   '',
#   'my',
#   'bid',
#   'me',
#   'fare',
#   'cypress',
#   'path',
#   'blood',
#   'where',
#   'cross',
#   "'twas",
#   'on',
#   'hill',
#   'i',
#   'met',
#   'you',
#   'my',
#   '',
#   'painted',
#   'windows',
#   'burn',
#   'flame',
#   'up',
#   'through',
#   'these',
#   'were',
#   'my',
#   'then',
#   'you',
#   'came',
#   'with',
#   'flowers',
#   'hair,',
#   'this',
#   'river',
#   'seem',
#   'some',
#   'grecian',
#   'stream',
#   '',
#   'when',
#   'fierce',
#   'our',
#   'race',
#   'his',
#   'lust',
#   'you',
#   'spring',
#   'within',
#   'smiling',
#   'my',
#   'o',
#   'golden',
#   'love',
#   'you',
#   'gave',
#   'me',
#   'alone',
#   'has',
#   'yet',
#   'will',
#   'save',
#   'me',
#   '',
#   'perchance',
#   'we',
#   'have',
#   'no',
#   'city',
#   'beyond',
#   'these',
#   'our',
#   'till',
#   'death',
#   'alone',
#   'sacred',
#   'pity',
#   'wash',
#   'with',
#   'long',
#   'sleep',
#   'our',
#   'so',
#   'much',
#   'more',
#   'i',
#   'praise',
#   'gods',
#   'you,',
#   'my',
#   '',
#   '',
#   '',
#   ''],
#  ['room',
#   'over',
#   'river',
#   '',
#   '',
#   'good-night,',
#   'my',
#   'love,',
#   'wan',
#   'moon',
#   'her',
#   'high,',
#   'softly',
#   'with',
#   'light',
#   'sky,',
#   'tides',
#   'swift',
#   'bright',
#   'into',
#   'sea',
#   '',
#   'sounds',
#   'come',
#   'us,',
#   'faint',
#   'with',
#   'passion',
#   'this',
#   'night,',
#   'one',
#   'little',
#   'dream',
#   'hangs',
#   'luminous',
#   'above',
#   'you',
#   'light;',
#   'roses',
#   'stars',
#   'bright',
#   'dew',
#   'draw',
#   'down',
#   'you',
#   '',
#   'how',
#   'dewy',
#   'heard',
#   'above',
#   'singing',
#   'your',
#   'his',
#   'lonely',
#   'song',
#   'love',
#   'he',
#   'too,',
#   'sad',
#   'heart,',
#   'hath',
#   'turned',
#   'rest,',
#   'sleep',
#   'is',
#   'best',
#   '',
#   'flower',
#   'my',
#   'let',
#   'us',
#   'be',
#   'true',
#   'youth',
#   'love',
#   'all',
#   'delight,',
#   'clean',
#   'one',
#   'with',
#   'you',
#   'i',
#   'would',
#   'be',
#   'ever',
#   'as',
#   'not',
#   'what',
#   'day',
#   'will',
#   'nor',
#   '',
#   'now',
#   'moon',
#   'is',
#   'away,',
#   'far',
#   'off',
#   'her',
#   'lost',
#   'sunken',
#   'day,',
#   'they',
#   'vanish',
#   'air',
#   'good-night,',
#   'my',
#   'love,',
#   'good-night,',
#   '',
#   '',
#   '',
#   ''],
#  ['fiddler',
#   '',
#   '',
#   'once',
#   'more',
#   'i',
#   'thought',
#   'i',
#   'heard',
#   'him',
#   'that',
#   'fiddler',
#   'under',
#   'timid',
#   'twilight',
#   'moon,',
#   'playing',
#   'his',
#   '',
#   'no',
#   'other',
#   'soul',
#   'was',
#   'place',
#   'as',
#   'up',
#   'hill',
#   'i',
#   'came',
#   'though',
#   'once',
#   'i',
#   'heard',
#   'him',
#   'every',
#   'day,',
#   'i',
#   'never',
#   'once',
#   'have',
#   'seen',
#   'his',
#   'face',
#   '',
#   'it',
#   'was',
#   'my',
#   'year,',
#   'when',
#   'came',
#   'blood',
#   'he',
#   'too,',
#   'was',
#   'then',
#   'now',
#   'separate',
#   'we',
#   'wander',
#   'here',
#   '',
#   'sometimes',
#   'his',
#   'ghostly',
#   'broke',
#   'on',
#   'my',
#   'dream',
#   'at',
#   'dawn',
#   'day,',
#   'through',
#   'my',
#   'window',
#   'may',
#   '',
#   'sometimes',
#   'lanes',
#   'i',
#   'heard',
#   'bird,',
#   'as',
#   'hidden',
#   'from',
#   'moon,',
#   'his',
#   'music',
#   'stirred',
#   '',
#   'o',
#   'happy',
#   'how',
#   'seemed',
#   'dream',
#   'i',
#   'those',
#   'dear',
#   'that',
#   'one',
#   'torrent',
#   'streamed',
#   '',
#   'when',
#   'moon',
#   'stars',
#   'go',
#   'out',
#   'i',
#   'am',
#   'dead',
#   'this',
#   'autumn',
#   'city',
#   'i',
#   'have',
#   'will',
#   'know',
#   'me',
#   'not,',
#   'but',
#   'he',
#   'will',
#   '',
#   'faded',
#   'he',
#   'will',
#   'play',
#   'some',
#   'other',
#   'brief',
#   'morn',
#   'away,',
#   'till',
#   'windows',
#   'palely',
#   'burn',
#   'amid',
#   'gray',
#   '',
#   'i',
#   'seem',
#   'know',
#   'i',
#   'shall',
#   'not',
#   'his',
#   'phantom',
#   'more',
#   'than',
#   'death',
#   'or',
#   'pain,',
#   'this',
#   'ghost',
#   'will',
#   'where',
#   'i',
#   'go',
#   '',
#   'some',
#   'untroubled',
#   'where',
#   'souls',
#   'like',
#   'mine',
#   'may',
#   'dwell,',
#   'i',
#   'shall',
#   'look',
#   'up',
#   'hear',
#   'his',
#   'note',
#   'across',
#   '',
#   'no',
#   'will',
#   'gather',
#   'at',
#   'his',
#   'tune',
#   'dance',
#   'their',
#   'ghostly',
#   'only',
#   'that',
#   'lonely',
#   'voice',
#   'will',
#   'everlasting',
#   '',
#   '',
#   '',
#   ''],
#  [],
#  ['s',
#   'page',
#   '',
#   '',
#   '',
#   'blaze',
#   'curls',
#   'he',
#   'way',
#   'before',
#   'tall',
#   'no',
#   'blossom',
#   'like',
#   'this',
#   'by',
#   'or',
#   'or',
#   'that',
#   'i',
#   'have',
#   'heard',
#   'him',
#   'down',
#   'singing',
#   'ere',
#   'morn',
#   'shattered',
#   'my',
#   'happy',
#   'dream',
#   'upon',
#   'weeping',
#   'i',
#   'awoke',
#   '',
#   'we',
#   'had',
#   'music',
#   'sweet',
#   'as',
#   'as',
#   'this',
#   'full',
#   'rich',
#   'gentle',
#   '',
#   'that',
#   'other',
#   'england',
#   'lives',
#   'thee,',
#   'thou',
#   'spray',
#   'thou',
#   'flower',
#   '',
#   '',
#   '',
#   ''],
#  ['dull',
#   'sunday',
#   '',
#   '',
#   '',
#   '',
#   'it',
#   'has',
#   'been',
#   'long',
#   'day,',
#   'long,',
#   'long',
#   'day;',
#   'now',
#   'floods',
#   'twilight,',
#   'long',
#   'green',
#   'waves',
#   'sunset',
#   'softly',
#   'evening',
#   'it',
#   'is',
#   'evening',
#   'over',
#   'great',
#   'it',
#   'is',
#   'evening',
#   'our',
#   'hearts',
#   '',
#   'though',
#   'last',
#   'frail',
#   'flowers',
#   'incense',
#   'have',
#   'long',
#   'around',
#   'i',
#   'hear',
#   'thin',
#   'white',
#   'voices',
#   'little',
#   'little',
#   'calling',
#   'name',
#   'his',
#   'most',
#   'sacred',
#   'heart,',
#   'singing',
#   'about',
#   'kind',
#   'little',
#   'all',
#   'golden',
#   'like',
#   'one',
#   'seen',
#   'by',
#   'an',
#   'old,',
#   'ages',
#   '',
#   'this',
#   'faith',
#   'she',
#   'live',
#   'die',
#   '',
#   '',
#   '',
#   'poems',
#   'whose',
#   'titles',
#   'are',
#   'body',
#   'as',
#   'have',
#   'had',
#   'their',
#   'titles',
#   'as',
#   'seen',
#   'contents',
#   'body',
#   'this',
#   'they',
#   'are',
#   'as',
#   'an',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'end',
#   'by',
#   'e',
#   'estlin',
#   'cummings',
#   's',
#   'foster',
#   'damon',
#   'j',
#   'r',
#   'dos',
#   'passos',
#   'robert',
#   'hillyer',
#   'r',
#   's',
#   'mitchell',
#   '',
#   '']]

# %%
from gensim import corpora

dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# %% [markdown]
# ### Train and LDA model using gensim to call MALLET
# > You need to specify the path to your MALLET install. On windows this will be smoething like C:\\mallet-2.0.8\\bin.

# %%
import gensim

model = gensim.models.wrappers.LdaMallet('mallet-2.0.8/bin/mallet', 
                corpus=corpus, 
                num_topics=13,
                id2word=dictionary)

# %% [markdown]
# ### Evaluate whether the resulting topics look reasonable

# %%
from pprint import pprint
pprint(model.print_topics())
# Out:
# [(0,
#   '0.076*"night" + 0.047*"moon" + 0.040*"love" + 0.039*"light" + 0.038*"song" '
#   '+ 0.033*"dark" + 0.025*"trees" + 0.023*"voice" + 0.022*"high" + '
#   '0.019*"thought"'),
#  (1,
#   '0.035*"dawn" + 0.029*"music" + 0.020*"hear" + 0.019*"sound" + 0.014*"gleam" '
#   '+ 0.014*"sunlight" + 0.013*"dead" + 0.012*"summer" + 0.012*"moonlight" + '
#   '0.011*"fingers"'),
#  (2,
#   '0.028*"thou" + 0.014*"face" + 0.014*"eyes" + 0.010*"gaze" + 0.010*"half" + '
#   '0.009*"and," + 0.009*"lonely" + 0.008*"wide" + 0.007*"mist" + 0.007*"hath"'),
#  (3,
#   '0.039*"time" + 0.036*"silent" + 0.033*"stars" + 0.032*"eyes" + '
#   '0.029*"golden" + 0.028*"life" + 0.028*"waters" + 0.024*"pale" + 0.021*"day" '
#   '+ 0.021*"great"'),
#  (4,
#   '0.030*"thou" + 0.022*"gods" + 0.016*"night," + 0.015*"thee" + 0.014*"gold," '
#   '+ 0.011*"face" + 0.010*"dead," + 0.010*"things," + 0.010*"earth\'s" + '
#   '0.009*"hills"'),
#  (5,
#   '0.018*"flowers" + 0.011*"mine" + 0.010*"shine" + 0.010*"dear" + '
#   '0.010*"thou" + 0.009*"stand" + 0.008*"silence" + 0.008*"lights" + '
#   '0.008*"garden" + 0.008*"deeds"'),
#  (6,
#   '0.014*"oh," + 0.013*"sea" + 0.012*"years" + 0.012*"lost" + 0.011*"phantoms" '
#   '+ 0.011*"watched" + 0.011*"desolate" + 0.011*"dim" + 0.010*"wake" + '
#   '0.010*"wings"'),
#  (7,
#   '0.053*"long" + 0.040*"soul" + 0.038*"heart" + 0.034*"men" + 0.033*"thy" + '
#   '0.023*"heart," + 0.021*"souls" + 0.020*"wide" + 0.019*"earth" + '
#   '0.018*"rain"'),
#  (8,
#   '0.012*"softly" + 0.010*"eyes" + 0.010*"grew" + 0.010*"branches" + '
#   '0.009*"earth" + 0.009*"immortal" + 0.009*"god" + 0.008*"sad" + 0.007*"dim," '
#   '+ 0.007*"aerial"'),
#  (9,
#   '0.016*"web" + 0.011*"red" + 0.010*"loud" + 0.009*"bridge" + 0.008*"amid" + '
#   '0.008*"white" + 0.008*"tangled" + 0.008*"breeze" + 0.008*"green" + '
#   '0.007*"dark"'),
#  (10,
#   '0.019*"land" + 0.018*"faint" + 0.017*"wind" + 0.017*"dreams" + 0.012*"days" '
#   '+ 0.011*"black" + 0.011*"then," + 0.011*"sea" + 0.010*"fairy" + '
#   '0.010*"unknown"'),
#  (11,
#   '0.021*"beauty" + 0.020*"strange" + 0.018*"rose," + 0.016*"crimson" + '
#   '0.015*"dead" + 0.014*"youth" + 0.013*"love" + 0.013*"more," + '
#   '0.013*"rapture!" + 0.012*"deep"'),
#  (12,
#   '0.014*"street" + 0.011*"pass" + 0.010*"black" + 0.008*"marble" + '
#   '0.008*"band" + 0.008*"ye" + 0.007*"sails" + 0.007*"break" + '
#   '0.006*"suddenly" + 0.006*"hung"')]

# %%
# %matplotlib inilne
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-e9cc0631f9a6> in <module>()
# ----> 1 get_ipython().magic('matplotlib inilne')
#
# ~/anaconda/envs/prog_hist_env2/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2144         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2145         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2146         return self.run_line_magic(magic_name, magic_arg_s)
#    2147
#    2148     #-------------------------------------------------------------------------
#
# ~/anaconda/envs/prog_hist_env2/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2065                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2066             with self.builtin_trap:
# -> 2067                 result = fn(*args,**kwargs)
#    2068             return result
#    2069
#
# <decorator-gen-107> in matplotlib(self, line)
#
# ~/anaconda/envs/prog_hist_env2/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda/envs/prog_hist_env2/lib/python3.6/site-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~/anaconda/envs/prog_hist_env2/lib/python3.6/site-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    2916         """
#    2917         from IPython.core import pylabtools as pt
# -> 2918         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    2919
#    2920         if gui != 'inline':
#
# ~/anaconda/envs/prog_hist_env2/lib/python3.6/site-packages/IPython/core/pylabtools.py in find_gui_and_backend(gui, gui_select)
#     267     """
#     268
# --> 269     import matplotlib
#     270
#     271     if gui and gui != 'auto':
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
! conda install matplotlib --yes
# Out:
# Fetching package metadata ...............
# Solving package specifications: .
#
# Package plan for installation in environment /Users/thomasj/anaconda/envs/prog_hist_env2:
#
# The following NEW packages will be INSTALLED:
#
#     cycler:     0.10.0-py36_0 conda-forge
#     matplotlib: 2.0.2-py36_1  conda-forge
#     pyparsing:  2.2.0-py36_0  conda-forge
#     pytz:       2017.2-py36_0 conda-forge
#
# pyparsing-2.2. 100% |################################| Time: 0:00:00 543.29 kB/s
# pytz-2017.2-py 100% |################################| Time: 0:00:00   1.10 MB/s
# cycler-0.10.0- 100% |################################| Time: 0:00:00   2.80 MB/s
# matplotlib-2.0 100% |################################| Time: 0:00:01   3.93 MB/s       | Time: 0:00:00   1.92 MB/s2.0  23% |#######                         | Time: 0:00:00   2.55 MB/sme: 0:00:00   2.94 MB/s##############                 | Time: 0:00:01   3.00 MB/s   3.30 MB/s##########          | Time: 0:00:01   3.51 MB/ss#######  | Time: 0:00:01   3.87 MB/s

# %%
model.print_topics().plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-bf560af6fc3a> in <module>()
# ----> 1 model.print_topics().plot()
#
# AttributeError: 'list' object has no attribute 'plot'
