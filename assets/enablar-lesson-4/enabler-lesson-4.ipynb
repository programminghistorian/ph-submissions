# %% [markdown]
# <h1 style="color:#800020;">'Terms and Conditions Apply': Intrepreting AI Tool Licences in Research Contexts through Natural Language Processing</h1>

# %% [markdown]
# This Jupyter Notebook, hosted online, offers an alternative to running a local Jupyter host, and downloading packages locally via Conda (as our main lesson instructs).
#
# If you are using an institutional device, or have limited disk memory, this online version may prove more intuitive.

# %%
# if you have not already downloaded the following packages locally

# %pip install pdfplumber
# %pip install pandas
# %pip install spacy
# Out:
# Requirement already satisfied: pdfplumber in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (0.11.9)
# Requirement already satisfied: pdfminer.six==20251230 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from pdfplumber) (20251230)
# Requirement already satisfied: Pillow>=9.1 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from pdfplumber) (12.2.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from pdfplumber) (5.7.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from pdfminer.six==20251230->pdfplumber) (3.4.5)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from pdfminer.six==20251230->pdfplumber) (47.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: spacy in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (0.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (2.4.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (80.10.2)
# Requirement already satisfied: packaging>=20.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.2.25)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: typer>=0.24.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (0.24.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.1)
# Requirement already satisfied: wrapt in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.1.2)
# Requirement already satisfied: click>=8.2.1 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/joenockels/miniforge3/envs/licence_nlp/lib/python3.11/site-packages (from jinja2->spacy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h2> Step 1: Python packages upload </h2>

# %%
# import packages from pre-loaded libraries

from pathlib import Path
import pandas as pd
import pdfplumber
import warnings

# %% [markdown]
# <h2> Step 2: Dataset and spaCy Deployment </h2>

# %%
ROOT = Path("AI_Products_TOS")  # in our case, this contains a folder structure of 29 licences, 
# for your own use simply change the filepath to your own

# Sense check that the file download is correct

next(ROOT.rglob("*.pdf"))  # first PDF it finds
print("Testing:", pdf_path)

# %%
# verify successful PDF extraction 
text = extract_pdf_text(pdf_path)
print("Chars:", len(text))
print(text[:1500])  # preview first 1500 characters
warnings.filterwarnings("ignore", message="Could not get FontBBox from font descriptor.*") # silence warnings, after verifying that pdfplumber is accurate

# %%
# optional, you can verify that pathlib has found your files, but returning the amount of files found, [1] if only working on a single licence

pdfs = list(ROOT.rglob("*.pdf"))
print("Found PDFs:", len(pdfs))
for p in pdfs[:10]:
    print(p)

# %%
# import NLP parsers 
import spacy
from spacy.matcher import PhraseMatcher, Matcher
nlp = spacy.load("en_core_web_sm") # main English model

# %% [markdown]
# <h2>Step 3: Dictionary set up</h2>

# %%
# empty template, look at main lesson text for further explanation 

name_of_dictionary = {

"risk or AI_theme": {

"associated phrases": [
    "phrase", 
    "phrase",
    "phrase",
    ],

"patterns": [
    [   
        {"term"},
    ],
    ]
},
}

# %%
# dictionary phrae and pattern example, look at main lesson text for further explanation

name_of_dictionary = {
    
"AI_TRAINING": {

"phrases": [
    "train",
    "improve",
    "enhance the capabilities",
    "develops",
    "automated techniques",
    "generate outputs",
    "computational analysis",
],

"patterns": [

    [
        {"LEMMA": "train"}, # lemmatises word to stem, accounting for ‘train’ and ‘training’
        {"OP": "?"}, # denotes a placeholder
        {"OP": "?"},
        {"LOWER": {"IN": ["model","system","algorithm"]}} # more targeted to avoid duplication, also reduces flattening dataset through full lowercasing 
    ],

    [
        {"LEMMA": "improve"},
        {"OP": "?"},
        {"OP": "?"},
        {"LOWER": {"IN": ["model","system","service"]}}
    ], 
 
    [   {"LEMMA": "enhance"},
        {"OP": "?"},
        {"OP": "?"},
        {"LOWER": {"IN": ["model","system","algorithm", "service"]}} 
    ],
    
    [   {"LEMMA": "develop"},
        {"OP": "?"},
        {"OP": "?"},
        {"LOWER": {"IN": ["model","system","algorithm", "service"]}} 
    ],
    [   {"LEMMA": "automate"},
        {"OP": "?"},
        {"OP": "?"},
        {"LOWER": {"IN": ["system","technique","performance", "service"]}} 
    ],
    [   {"LEMMA": "generate"},
        {"OP": "?"},
        {"OP": "?"},
        {"LOWER": {"IN": ["output","response","content", "information"]}} 
    ],
    [   {"LEMMA": "computation"},
        {"OP": "?"},
        {"OP": "?"},
        {"LOWER": {"IN": ["analysis"]}} 
    ],
]
},
}

# %% [markdown]
# <h2>Step 4: Running PhraseMatcher</h2>

# %%
# load NLP matchers
phrase_matcher = PhraseMatcher(nlp.vocab)
token_matcher = Matcher(nlp.vocab)

# %%
for category, rules in red_flag_dict.items(): # establishes the rubric of your dictionary
    phrase_matcher.add(category, [nlp.make_doc(p) for p in rules.get("phrases", [])])
    token_matcher.add(category, rules.get("patterns", []))

# %%
print("Loaded categories:", list(red_flag_dict.keys())) # verify that the dictionary is properly loaded

# %%
# establish a function to add red flag ‘hits’ into an empty list, covering the entire length of your agreement(s)

def extract_pdf_text(pdf_path):
parts = []
with pdfplumber.open(str(pdf_path)) as pdf:
    for page in pdf.pages:
        parts.append(page.extract_text() or "")
return "\n".join(parts)

pdf_path = pdfs[0]
text = extract_pdf_text(pdf_path)
doc = nlp(text)

matches = []

for match_id, start, end in phrase_matcher(doc):
    span = doc[start:end]
    matches.append((nlp.vocab.strings[match_id], span.text, span.sent.text, "phrase"))

for match_id, start, end in token_matcher(doc):
    span = doc[start:end]
    matches.append((nlp.vocab.strings[match_id], span.text, span.sent.text, "pattern"))

# %%
# sense check, checking the first ten recorded matches (hits)

print("Testing:", pdf_path)
print("Matches:", len(matches))
matches[:10]

# silence pdfplumber warnings, as we have verified that the text has been extracted with enough accuracy (see discussion in main lesson)
warnings.filterwarnings("ignore", message="Could not get FontBBox from font descriptor.*")

# %% [markdown]
# <h2>Step 5: Red Flag Exportation</h2>

# %%
# retains .xlsv file structure, with folder headings 

rows = []
    for pdf_path in pdfs:
    folder = pdf_path.relative_to(ROOT).parts[0]
    text = extract_pdf_text(pdf_path)
    doc = nlp(text)

for match_id, start, end in phrase_matcher(doc):
    span = doc[start:end]
    rows.append({
        "folder": folder,
        "file": str(pdf_path.relative_to(ROOT)),
        "rule": nlp.vocab.strings[match_id],
        "match_text": span.text,
        "sentence": span.sent.text,
        "method": "phrase",
    })

for match_id, start, end in token_matcher(doc):
    span = doc[start:end]
    rows.append({
        "folder": folder,
        "file": str(pdf_path.relative_to(ROOT)),
        "rule": nlp.vocab.strings[match_id],
        "match_text": span.text,
        "sentence": span.sent.text,
        "method": "pattern",
    })

# silence the spaCy text extraction warning, as we have verified its accuracy

warnings.filterwarnings("ignore", message="Could not get FontBBox from font descriptor.*")

# %%
# drop any remaining duplicates, for fair and robust analysis 

df = df.drop_duplicates(subset=["file","rule","sentence","method"])

# %%
# quick view of the first five match (hit) results 

df = pd.DataFrame(matches)

df.head()

# %%
# optional, but can also use SpaCy for noun detection and extraction, to direct further assessment of AI risks (if you have a particular use case)

noun_phrases = set()

for chunk in doc.noun_chunks:
    noun_phrases.add(chunk.text.lower())

for np in list(noun_phrases)[:20]:
    print(np) # returns first twenty results

# %%
# for exporting one licence 

 out_path = Path("red_flags_by_folder.xlsx")
 with pd.ExcelWriter(out_path, engine="openpyxl") 
 out_path

# %%
# if exporting multiple licences 

 out_path = Path("red_flags_by_folder.xlsx")
 with pd.ExcelWriter(out_path, engine="openpyxl") as writer:
 for folder in sorted({p.relative_to(ROOT).parts[0] for p in pdfs}):
      sheet = folder[:31]
      sub = df[df["folder"] == folder].drop(columns=["folder"])
      sub.to_excel(writer, sheet_name=sheet, index=False)

 out_path
